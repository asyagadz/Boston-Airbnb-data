# %% [markdown]
# I will perform the data cleaning and feature engineering steps into the same notebook, due to the fact that there involve less steps than usual: dropping columns with missing values, computing missing values, creating new features etc. In larger projects, they should be split:
#
# Initial analysis <br>
# Data cleaning<br>
# Feature Engineering <br>
# Feature Selection <br>
# Pipeline<br>
# Prediction run<br>

# %%
import pandas as pd
import numpy as np

import regex as re
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick 
import matplotlib.dates as mdates
from matplotlib.ticker import PercentFormatter, FuncFormatter
# %matplotlib inline
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)
from cycler import cycler

import seaborn as sns
sns.set()

import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from textacy import preprocessing
import textacy
from nltk.corpus import stopwords
from nltk.stem import *

import spacy
nlp = spacy.load('en_core_web_sm')

from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from  sklearn.metrics  import accuracy_score
from sklearn import metrics
from sklearn.metrics import confusion_matrix
# for one hot encoding with sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import VarianceThreshold

# for the Q-Q plots
import scipy.stats as stats


# for one hot encoding with feature-engine
from feature_engine.encoding import OneHotEncoder as fe_OneHotEncoder

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import roc_auc_score, r2_score, mean_squared_error
# environment settings
pd.set_option('display.max_column',None)
pd.set_option('display.max_rows',None)

# %%
#read data
calendar = pd.read_csv('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/raw_data/calendar.csv')
listings =  pd.read_csv('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/raw_data/listings.csv')
reviews = pd.read_csv('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/raw_data/reviews.csv')

# %% [markdown]
# From the previous notebook, in which we initially explored the data, we have defined the folling questions to answer:
# 1. When are the busiest times in Boston? Which are the busiest neghbourhoods?
# I will perform some descriptive statistics and visualisations.
# In order to answer that, we will use the calendar data create occupancy metrics based on calendar data, to understand the occupancy levels throughout the year. Add to this data the neighbourhood information.
# 2. What drives/defines the prices of the AirBNB in Boston? Which are the top variables that affect the price?
# We will build a regression model to predict a continuous variable, and to understand the features that drive the model.
# 3. What drives the occupancy rates of the AirBNBs in Boston? Which are more engaged than others? What are the factors/variables that define higher occupancy rates?
# We will discretize the occupancy rates into several categories, and then build a multi-class classification model to predict the occupancy rates.

# %% [markdown]
# # 1. Data cleaning

# %% [markdown]
# ### Check for duplicates, columns with repeated values, drop unnecessary columns

# %% [markdown]
# ####  Calendar data

# %%
calendar.shape
# Out:
# (1308890, 4)

# %%
calendar.drop_duplicates(subset=['listing_id','date'],inplace=True)

# %%
calendar.shape
# Out:
# (1308525, 4)

# %%
calendar['date'] = pd.to_datetime(calendar['date'])
calendar['month'] = calendar['date'].map(lambda x: x.strftime('%Y-%m'))
#calendar['week'] = calendar['date'].map(lambda x: x.strftime("%V"))

# %%
cal_month_avail = calendar.groupby(['listing_id','month','available']).agg({'date':'nunique'}).reset_index()

# %%
cal_month_total = cal_month_avail.groupby(['listing_id','month']).agg({'date':'sum'}).reset_index()
cal_month_total.rename({'date':'total_days'},inplace=True,axis=1)

# %%
cal_month_busy = cal_month_avail[cal_month_avail['available']=='f'].groupby(['listing_id','month']).agg({'date':'sum'}).reset_index()
cal_month_busy.rename({'date':'busy_days'},inplace=True,axis=1)

# %%
cal_month_total = cal_month_total.merge(cal_month_busy, how = 'left', on = ['listing_id','month'])

# %%
cal_month_total['busy_days'].fillna(0,inplace=True)
cal_month_total['occupancy_metrics'] = cal_month_total['busy_days']/cal_month_total['total_days']*100

# %%
cal_metrics_total = cal_month_total.groupby(['listing_id']).agg({'total_days':'sum','busy_days':'sum'}).reset_index()
#cal_metrics_total.sort_values(by='occupancy_metrics',ascending =False).head()

# %%
cal_metrics_total['occupancy_metrics'] = round(cal_metrics_total['busy_days']/cal_metrics_total['total_days']*100,0)

# %%
cal_metrics_total.head()
# Out:
#    listing_id  total_days  busy_days  occupancy_metrics
# 0        3353         365      116.0               32.0
# 1        5506         365       21.0                6.0
# 2        6695         365       41.0               11.0
# 3        6976         365       46.0               13.0
# 4        8792         365      117.0               32.0

# %%
cal_metrics_total.shape
# Out:
# (3585, 4)

# %%
#20% of the listings are fully booked throughout the year
cal_metrics_total[cal_metrics_total['occupancy_metrics']==100].shape
# Out:
# (705, 4)

# %%
cal_metrics_total[cal_metrics_total['occupancy_metrics']<=40].shape
# Out:
# (1660, 4)

# %%
calendar.to_pickle('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/processed/calendar.pkl')
cal_month_total.to_pickle('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/processed/calendar_metrics_monthly.pkl')
cal_metrics_total.to_pickle('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/processed/calendar_metrics.pkl')

# %% [markdown]
# #### Listings data

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.585000e+03  3.585000e+03  3.585000e+03          3585.000000
# mean   8.440875e+06  2.016091e+13  2.492311e+07            58.902371
# std    4.500787e+06  8.516813e-01  2.292781e+07           171.119663
# min    3.353000e+03  2.016091e+13  4.240000e+03             0.000000
# 25%    4.679319e+06  2.016091e+13  6.103425e+06             1.000000
# 50%    8.577620e+06  2.016091e+13  1.928100e+07             2.000000
# 75%    1.278953e+07  2.016091e+13  3.622147e+07             7.000000
# max    1.493346e+07  2.016091e+13  9.385411e+07           749.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                3585.000000                           0.0  3585.000000
# mean                   58.902371                           NaN    42.340032
# std                   171.119663                           NaN     0.024403
# min                     0.000000                           NaN    42.235942
# 25%                     1.000000                           NaN    42.329995
# 50%                     2.000000                           NaN    42.345201
# 75%                     7.000000                           NaN    42.354685
# max                   749.000000                           NaN    42.389982
#
#          longitude  accommodates    bathrooms     bedrooms         beds  \
# count  3585.000000   3585.000000  3571.000000  3575.000000  3576.000000
# mean    -71.084818      3.041283     1.221647     1.255944     1.609060
# std       0.031565      1.778929     0.501487     0.753060     1.011745
# min     -71.171789      1.000000     0.000000     0.000000     0.000000
# 25%     -71.105083      2.000000     1.000000     1.000000     1.000000
# 50%     -71.078429      2.000000     1.000000     1.000000     1.000000
# 75%     -71.062155      4.000000     1.000000     2.000000     2.000000
# max     -71.000100     16.000000     6.000000     5.000000    16.000000
#
#        square_feet  guests_included  minimum_nights  maximum_nights  \
# count    56.000000      3585.000000     3585.000000    3.585000e+03
# mean    858.464286         1.429847        3.171269    2.872584e+04
# std     608.874310         1.056787        8.874133    1.670136e+06
# min       0.000000         0.000000        1.000000    1.000000e+00
# 25%     415.000000         1.000000        1.000000    3.650000e+02
# 50%     825.000000         1.000000        2.000000    1.125000e+03
# 75%    1200.000000         1.000000        3.000000    1.125000e+03
# max    2400.000000        14.000000      300.000000    1.000000e+08
#
#        has_availability  availability_30  availability_60  availability_90  \
# count               0.0       3585.00000      3585.000000      3585.000000
# mean                NaN          8.64993        21.833194        38.558159
# std                 NaN         10.43533        21.860966        33.158272
# min                 NaN          0.00000         0.000000         0.000000
# 25%                 NaN          0.00000         0.000000         0.000000
# 50%                 NaN          4.00000        16.000000        37.000000
# 75%                 NaN         15.00000        40.000000        68.000000
# max                 NaN         30.00000        60.000000        90.000000
#
#        availability_365  number_of_reviews  review_scores_rating  \
# count       3585.000000        3585.000000           2772.000000
# mean         179.346444          19.044630             91.916667
# std          142.136180          35.571658              9.531686
# min            0.000000           0.000000             20.000000
# 25%           19.000000           1.000000             89.000000
# 50%          179.000000           5.000000             94.000000
# 75%          325.000000          21.000000             98.250000
# max          365.000000         404.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             2762.000000                2767.000000
# mean                 9.431571                   9.258041
# std                  0.931863                   1.168977
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            2765.000000                  2767.000000
# mean                9.646293                     9.646549
# std                 0.762753                     0.735507
# min                 2.000000                     4.000000
# 25%                 9.000000                     9.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  license  \
# count             2763.000000          2764.000000      0.0
# mean                 9.414043             9.168234      NaN
# std                  0.903436             1.011116      NaN
# min                  2.000000             2.000000      NaN
# 25%                  9.000000             9.000000      NaN
# 50%                 10.000000             9.000000      NaN
# 75%                 10.000000            10.000000      NaN
# max                 10.000000            10.000000      NaN
#
#        jurisdiction_names  calculated_host_listings_count  reviews_per_month
# count                 0.0                     3585.000000        2829.000000
# mean                  NaN                       12.733891           1.970908
# std                   NaN                       29.415076           2.120561
# min                   NaN                        1.000000           0.010000
# 25%                   NaN                        1.000000           0.480000
# 50%                   NaN                        2.000000           1.170000
# 75%                   NaN                        6.000000           2.720000
# max                   NaN                      136.000000          19.150000

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
# 3  Roslindale is a lovely little neighborhood loc...
# 4  I love the proximity to downtown, the neighbor...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
# 3  Please be mindful of the property as it is old...
# 4  I have one roommate who lives on the lower lev...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
# 3  There are buses that stop right in front of th...
# 4  From Logan Airport  and South Station you have...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
# 3  The basement has a washer dryer and gym area. ...
# 4  You will have access to the front and side por...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3  We do live in the house therefore might be som...
# 4  I love my city and really enjoy sharing it wit...
#
#                                          house_rules  \
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 2  I encourage you to use my kitchen, cooking and...
# 3  - The bathroom and house are shared so please ...
# 4  Please no smoking in the house, porch or on th...
#
#                                        thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                           medium_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                          picture_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                       xl_picture_url   host_id  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...  31303940
# 1  https://a1.muscache.com/im/pictures/39327812/d...   2572247
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...     16701
# 3  https://a2.muscache.com/im/pictures/39764190-1...   6031442
# 4  https://a1.muscache.com/im/pictures/97154760/8...  15396970
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia  2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
# 2     https://www.airbnb.com/users/show/16701      Phil  2009-05-11
# 3   https://www.airbnb.com/users/show/6031442    Meghna  2013-04-21
# 4  https://www.airbnb.com/users/show/15396970     Linda  2014-05-11
#
#                           host_location  \
# 0  Boston, Massachusetts, United States
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
# 3  Boston, Massachusetts, United States
# 4  Boston, Massachusetts, United States
#
#                                           host_about  host_response_time  \
# 0  We are country and city connecting in our deck...                 NaN
# 1  I live in Boston and I like to travel and have...      within an hour
# 2  I am a middle-aged, single male with a wide ra...  within a few hours
# 3  My husband and I live on the property.  He’s a...  within a few hours
# 4  I work full time for a public school district....      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1               100%                 100%                 f
# 2               100%                  88%                 t
# 3               100%                  50%                 f
# 4               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...
# 1  https://a2.muscache.com/im/users/2572247/profi...
# 2  https://a2.muscache.com/im/users/16701/profile...
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...
# 4  https://a0.muscache.com/im/users/15396970/prof...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...         Roslindale
# 1  https://a2.muscache.com/im/users/2572247/profi...         Roslindale
# 2  https://a2.muscache.com/im/users/16701/profile...         Roslindale
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...                NaN
# 4  https://a0.muscache.com/im/users/15396970/prof...         Roslindale
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    1                          1
# 2                    1                          1
# 3                    1                          1
# 4                    1                          1
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
# 2             ['email', 'phone', 'reviews', 'jumio']                    t
# 3                      ['email', 'phone', 'reviews']                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                                             street  \
# 0                      f      Birch Street, Boston, MA 02131, United States
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
# 2                      t        Ardale St., Boston, MA 02131, United States
# 3                      f                          Boston, MA, United States
# 4                      t    Durnell Avenue, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed    city  \
# 0    Roslindale             Roslindale                           NaN  Boston
# 1    Roslindale             Roslindale                           NaN  Boston
# 2    Roslindale             Roslindale                           NaN  Boston
# 3           NaN             Roslindale                           NaN  Boston
# 4    Roslindale             Roslindale                           NaN  Boston
#
#   state zipcode  market smart_location country_code        country   latitude  \
# 0    MA   02131  Boston     Boston, MA           US  United States  42.282619
# 1    MA   02131  Boston     Boston, MA           US  United States  42.286241
# 2    MA   02131  Boston     Boston, MA           US  United States  42.292438
# 3    MA     NaN  Boston     Boston, MA           US  United States  42.281106
# 4    MA   02131  Boston     Boston, MA           US  United States  42.284512
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0 -71.133068                 t         House  Entire home/apt             4
# 1 -71.134374                 t     Apartment     Private room             2
# 2 -71.135765                 t     Apartment     Private room             2
# 3 -71.121021                 f         House     Private room             4
# 4 -71.136258                 t         House     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.5       2.0   3.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
# 3        1.0       1.0   2.0  Real Bed
# 4        1.5       1.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...          NaN  $250.00
# 1  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $65.00
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...          NaN   $65.00
# 3  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $75.00
# 4  {Internet,"Wireless Internet","Air Conditionin...          NaN   $79.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN       $35.00                1
# 1      $400.00           NaN           $95.00       $10.00                0
# 2      $395.00     $1,350.00              NaN          NaN                1
# 3          NaN           NaN          $100.00       $50.00                2
# 4          NaN           NaN              NaN       $15.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $0.00               2            1125      2 weeks ago
# 1        $0.00               2              15       a week ago
# 2       $20.00               3              45       5 days ago
# 3       $25.00               1            1125       a week ago
# 4        $0.00               2              31      2 weeks ago
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0               NaN                0                0                0
# 1               NaN               26               54               84
# 2               NaN               19               46               61
# 3               NaN                6               16               26
# 4               NaN               13               34               59
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0                 0            2016-09-06                  0          NaN
# 1               359            2016-09-06                 36   2014-06-01
# 2               319            2016-09-06                 41   2009-07-19
# 3                98            2016-09-06                  1   2016-08-28
# 4               334            2016-09-06                 29   2015-08-18
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0         NaN                   NaN                     NaN
# 1  2016-08-13                  94.0                    10.0
# 2  2016-08-05                  98.0                    10.0
# 3  2016-08-28                 100.0                    10.0
# 4  2016-09-01                  99.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
#
#   requires_license  license  jurisdiction_names instant_bookable  \
# 0                f      NaN                 NaN                f
# 1                f      NaN                 NaN                t
# 2                f      NaN                 NaN                f
# 3                f      NaN                 NaN                f
# 4                f      NaN                 NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               1
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                               1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25

# %%
missing_values = listings.isna().sum()/listings.shape[0]*100
missing_values.sort_values(ascending = False)
# Out:
# has_availability                    100.000000
# license                             100.000000
# neighbourhood_group_cleansed        100.000000
# jurisdiction_names                  100.000000
# square_feet                          98.437936
# monthly_price                        75.230126
# weekly_price                         75.118550
# security_deposit                     62.566248
# notes                                55.090656
# interaction                          43.347280
# access                               41.534170
# neighborhood_overview                39.470014
# host_about                           36.513250
# transit                              35.983264
# house_rules                          33.249651
# cleaning_fee                         30.878661
# space                                29.483961
# review_scores_accuracy               22.956764
# review_scores_location               22.928870
# review_scores_value                  22.900976
# review_scores_checkin                22.873082
# review_scores_communication          22.817294
# review_scores_cleanliness            22.817294
# review_scores_rating                 22.677824
# reviews_per_month                    21.087866
# last_review                          21.087866
# first_review                         21.087866
# xl_picture_url                       16.708508
# medium_url                           16.708508
# thumbnail_url                        16.708508
# neighbourhood                        15.146444
# host_response_time                   13.138075
# host_response_rate                   13.138075
# host_acceptance_rate                 13.138075
# host_neighbourhood                    9.456067
# summary                               3.988842
# zipcode                               1.059972
# bathrooms                             0.390516
# market                                0.390516
# host_location                         0.306834
# bedrooms                              0.278940
# beds                                  0.251046
# property_type                         0.083682
# city                                  0.055788
# cancellation_policy                   0.000000
# calculated_host_listings_count        0.000000
# require_guest_phone_verification      0.000000
# require_guest_profile_picture         0.000000
# instant_bookable                      0.000000
# guests_included                       0.000000
# extra_people                          0.000000
# minimum_nights                        0.000000
# maximum_nights                        0.000000
# calendar_updated                      0.000000
# number_of_reviews                     0.000000
# availability_30                       0.000000
# availability_60                       0.000000
# calendar_last_scraped                 0.000000
# availability_365                      0.000000
# requires_license                      0.000000
# availability_90                       0.000000
# id                                    0.000000
# price                                 0.000000
# host_total_listings_count             0.000000
# scrape_id                             0.000000
# last_scraped                          0.000000
# name                                  0.000000
# description                           0.000000
# experiences_offered                   0.000000
# picture_url                           0.000000
# host_id                               0.000000
# host_url                              0.000000
# host_name                             0.000000
# host_since                            0.000000
# host_is_superhost                     0.000000
# host_thumbnail_url                    0.000000
# host_picture_url                      0.000000
# host_listings_count                   0.000000
# host_verifications                    0.000000
# amenities                             0.000000
# host_has_profile_pic                  0.000000
# host_identity_verified                0.000000
# street                                0.000000
# neighbourhood_cleansed                0.000000
# state                                 0.000000
# smart_location                        0.000000
# country_code                          0.000000
# listing_url                           0.000000
# latitude                              0.000000
# longitude                             0.000000
# is_location_exact                     0.000000
# room_type                             0.000000
# accommodates                          0.000000
# bed_type                              0.000000
# country                               0.000000
# dtype: float64

# %%
listings.shape
# Out:
# (3585, 95)

# %%
#drop duplicates
listings.drop_duplicates(inplace=True)

# %%
listings.shape
# Out:
# (3585, 95)

# %% [markdown]
# ### Drop columns

# %%
#There are 5 columns with almost all missing values -> we are dropping them
listings.drop(columns={'has_availability','neighbourhood_group_cleansed','license','jurisdiction_names','square_feet'},inplace=True,axis = 1)

# %%
# drop the columns with the url - no need at this point
listings.drop(columns={'listing_url','thumbnail_url','medium_url','picture_url','xl_picture_url','availability_30','availability_60','availability_90','availability_365','maximum_nights','weekly_price','monthly_price','calendar_updated','host_picture_url','host_listings_count','neighbourhood'},inplace=True,axis = 1)

# %%
listings.shape
# Out:
# (3585, 74)

# %%
#find columns with the same value
col_list = []
for col in listings.columns:
    if listings[col].nunique()==1:
        col_list.append(col)

# %%
col_list
# Out:
# ['scrape_id',
#  'last_scraped',
#  'experiences_offered',
#  'state',
#  'country_code',
#  'country',
#  'calendar_last_scraped',
#  'requires_license']

# %%
# drop the columns with the same value
listings.drop(columns={'scrape_id',
 'last_scraped',
 'experiences_offered',
 'state',
 'country_code',
 'country',
 'calendar_last_scraped',
 'requires_license'},inplace=True,axis = 1)

# %%
#find columns that are dummy variables
col_list2 = []
for col in listings.columns:
    if listings[col].nunique()==2:
        col_list2.append(col)

# %%
#find columns with the three values
col_list2
# Out:
# ['host_is_superhost',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'is_location_exact',
#  'instant_bookable',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification']

# %%
#Transform categorical variables into Binary
for col in col_list2:
    listings[col] = np.where(listings[col]=='t', 1, 0)

# %%
#drop also column host_has_profile_pic, since the majority of the values are true
listings.drop('host_has_profile_pic',inplace=True, axis=1)

# %%
listings.shape
# Out:
# (3585, 65)

# %%
#for security deposit - my assumption is that when there is no value -> there is NO security deposit. Also for the cleaning fee - if omitted -> then there isn't one. THIS IS OK to be done before the SPLIT
listings['security_deposit'].fillna(0,inplace=True)
listings['cleaning_fee'].fillna(0,inplace=True)

# %%
#The text data contained in space, summary, description is almost the same, so I will leave only the description, since it has less missing values
listings.drop(['space','summary','name','host_url','host_name','host_thumbnail_url'],axis=1,inplace=True)

# %%
#column market contains very few values, and the majority of the values are only 1 value -> we will drop it
listings['market'].value_counts()
# Out:
# Boston                   3568
# San Francisco               1
# Other (Domestic)            1
# Other (International)       1
# Name: market, dtype: int64

# %%
listings.drop(['market'],axis=1,inplace=True)

# %%
#For the rest of the text variables, since there is a big part of them missing, I will encode them as 1: with data, 0 - no data
col_list = ['notes', 'transit','access','interaction','house_rules','neighborhood_overview','host_about']
for col in col_list:
    listings[col].fillna(0,inplace=True)
    listings[col] = np.where(listings[col].notna()==True, 1, 0)

# %%
listings.drop(columns={'notes', 'transit','access','interaction','house_rules','neighborhood_overview','host_about'},axis=1,inplace=True)

# %% [markdown]
# #Date variables we will transform into numerical:
# - host_since: days between last_day_reserved and host_since - we will get days into operation of the listing
# - last_review: days between last_review and last reservation
# - first_review: days between last_reservation and first_review  - we will omit this, since it is very close to the first metrics
#
# Binning and discretization should be done over the host response rate and host acceptance rate

# %%
listings['host_since']= pd.to_datetime(listings['host_since'])
listings['first_review']= pd.to_datetime(listings['first_review'])
listings['last_review']= pd.to_datetime(listings['last_review'])

# %%
cal_last_reservation = calendar[calendar['available']=='f'].groupby(['listing_id']).agg({'date':'max'}).reset_index()

# %%
listings = listings.merge(cal_last_reservation, how = 'left', left_on = 'id',right_on = 'listing_id')

# %%
#listings['days_operation'] = (listings['date']- listings['host_since']).dt.days
# date when the dataset was scrapped
last_scraped = pd.to_datetime("2016-09-07")
listings['days_operation'] = (last_scraped - listings['host_since']).dt.days
#listings['days_operation'].dtype()
#listings['days_operation'].dtype()

# %%
#new variable that gives the days between the last reservation and the last review
listings['days_review'] = (listings['date']- listings['last_review']).dt.days

# %%
listings.drop(columns={'host_since','last_review','first_review'},inplace=True,axis=1)

# %%
listings.drop(['date'],axis=1,inplace=True)

# %%
listings.drop(['listing_id','zipcode'],axis=1,inplace=True)

# %%
listings.describe(include='object').transpose()
# Out:
#                        count unique  \
# description             3585   3423
# host_location           3574    176
# host_response_time      3114      4
# host_response_rate      3114     52
# host_acceptance_rate    3114     72
# host_neighbourhood      3246     53
# host_verifications      3585     83
# street                  3585   1239
# neighbourhood_cleansed  3585     25
# city                    3583     38
# smart_location          3585     39
# property_type           3582     13
# room_type               3585      3
# bed_type                3585      5
# amenities               3585   3092
# price                   3585    324
# security_deposit        3585     55
# cleaning_fee            3585     80
# extra_people            3585     51
# cancellation_policy     3585      4
#
#                                                                       top  \
# description             The unit is stylishly designed for comfort, va...
# host_location                        Boston, Massachusetts, United States
# host_response_time                                         within an hour
# host_response_rate                                                   100%
# host_acceptance_rate                                                 100%
# host_neighbourhood                                       Allston-Brighton
# host_verifications                 ['email', 'phone', 'reviews', 'jumio']
# street                   Boylston Street, Boston, MA 02215, United States
# neighbourhood_cleansed                                      Jamaica Plain
# city                                                               Boston
# smart_location                                                 Boston, MA
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# bed_type                                                         Real Bed
# amenities                                                              {}
# price                                                             $150.00
# security_deposit                                                        0
# cleaning_fee                                                            0
# extra_people                                                        $0.00
# cancellation_policy                                                strict
#
#                         freq
# description                7
# host_location           2421
# host_response_time      1384
# host_response_rate      2072
# host_acceptance_rate    1210
# host_neighbourhood       375
# host_verifications       930
# street                    64
# neighbourhood_cleansed   343
# city                    3381
# smart_location          3381
# property_type           2612
# room_type               2127
# bed_type                3453
# amenities                 32
# price                    144
# security_deposit        2243
# cleaning_fee            1107
# extra_people            2211
# cancellation_policy     1582

# %%
#Transform the price columns to integer values
cols = ['security_deposit','price','cleaning_fee','extra_people']
for col in cols:
    listings[col] = listings[col].str.replace('$','')
    listings[col] = listings[col].str.replace(',','')
    #listings[col_col] = listings[col].str.findall('\d')
    listings[col].fillna(0,inplace=True)
    listings[col] = pd.to_numeric(listings[col])
# Out:
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/1907924909.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   listings[col] = listings[col].str.replace('$','')

# %%
listings['security_deposit'].head()
# Out:
# 0      0.0
# 1     95.0
# 2      0.0
# 3    100.0
# 4      0.0
# Name: security_deposit, dtype: float64

# %%
listings['price'].head()
# Out:
# 0    250.0
# 1     65.0
# 2     65.0
# 3     75.0
# 4     79.0
# Name: price, dtype: float64

# %%
col_objects = listings.select_dtypes('object').columns

# %%
for col in col_objects:
    print (col, listings[col].isna().sum())
# Out:
# description 0
# host_location 11
# host_response_time 471
# host_response_rate 471
# host_acceptance_rate 471
# host_neighbourhood 339
# host_verifications 0
# street 0
# neighbourhood_cleansed 0
# city 2
# smart_location 0
# property_type 3
# room_type 0
# bed_type 0
# amenities 0
# cancellation_policy 0

# %%
#Map host location to 1:within Boston, 0 - not in Boston
listings['host_location'] = np.where(listings['host_location']=='Boston, Massachusetts, United States', 1, 0)
listings['host_location'].fillna(1,inplace=True)

# %%
listings['host_response_time'].value_counts()
# Out:
# within an hour        1384
# within a few hours    1218
# within a day           469
# a few days or more      43
# Name: host_response_time, dtype: int64

# %% [markdown]
# For the 5 categorical variables with missing values and for all the numerical categoricals with missing value we will populate with mean/median and the mode/for the categorical ones/
# Before that, we need to study the distributions of the variables and perform EDA.
# Also check for the prerequisites of the Linear model /the assumptions/.
# + Feature selection techniques -> correlation, chi-square test<br>
# Categorical Encoding<br>
# __BEFORE ANY OTHER COMPUTATIONS, we need to split the dataset into TRAIN AND TEST set.__
# We can perform GridSearch without Cross Validation.

# %%
#as a result from the analysis in 02.1 notebook - dropping the description field
listings.drop(['description'],axis=1,inplace=True)

# %% [markdown]
# ### Exploratory Data Analysis - distributions

# %%
#sns.pairplot(listings)

# %%
'''
Input: dataframe and variable to be analysed
Output: variable descriptive statistics
'''

def diagnostic_plots(df, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.ylabel('Variable quantiles')

    # boxplot
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

# %%
diagnostic_plots(listings,'price')

# %% [markdown]
# Transform the price into price per person, as well as take into account the additional price for guests

# %%
listings['price_per_person'] = round(listings['price']/(listings['accommodates']+listings['guests_included']),2)+listings['extra_people']

# %%
listings.drop(['price','accommodates','guests_included','extra_people'],axis=1,inplace=True)

# %%
diagnostic_plots(listings,'price_per_person')

# %%
#drop the days_review column
listings.drop(columns=['days_review'],axis=1,inplace=True)

# %%
listings.drop(['host_id','street'],axis=1,inplace=True)

# %%
cols = ['host_response_rate','host_acceptance_rate']
for col in cols:
    listings[col] = listings[col].str.replace('%','')
    listings[col] = pd.to_numeric(listings[col])

# %%
listings.loc[listings['days_operation'].isna()==True]
# Out:
# Empty DataFrame
# Columns: [id, host_location, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_neighbourhood, host_total_listings_count, host_verifications, host_identity_verified, neighbourhood_cleansed, city, smart_location, latitude, longitude, is_location_exact, property_type, room_type, bathrooms, bedrooms, beds, bed_type, amenities, security_deposit, cleaning_fee, minimum_nights, number_of_reviews, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month, days_operation, price_per_person]
# Index: []

# %%
#calendar[calendar['listing_id']==2843445]

# %% [markdown]
# # 2. Missing values computations
# For the rest of the columns we will handle the missing values one by one
# IT IS VERY IMPORTANT BEFORE IMPUTING MISSING VALUES TO SPLIT THE DATA INTO TRAIN&TEST -> TO AVOID DATA LEAKAGE. __COMPUTATIONS SHOULD BE DONE ONLY ON THE TRAIN SET!__<br>
# Use sklearn SimpleImputer or other in-built imputers -> and place it in a Pipeline.

# %%
df = listings.drop(['price_per_person'],axis=1)
y = listings['price_per_person'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(df, # just the features
                                                    y, # the target
                                                    test_size=0.3, # the percentage of obs in the test set
                                                    random_state=42) # for reproducibility

# %%
X_train['beds'].value_counts()
# Out:
# 1.0     1521
# 2.0      667
# 3.0      192
# 4.0       67
# 5.0       28
# 6.0       11
# 7.0        7
# 8.0        5
# 0.0        2
# 9.0        1
# 16.0       1
# Name: beds, dtype: int64

# %%
X_test['beds'].value_counts()
# Out:
# 1.0    644
# 2.0    286
# 3.0     83
# 4.0     39
# 5.0     12
# 6.0      5
# 0.0      2
# 7.0      1
# 9.0      1
# 8.0      1
# Name: beds, dtype: int64

# %%
X_train['beds'].hist()
# Out:
# <AxesSubplot:>

# %%
X_train.hist(bins=50, figsize=(10,10))
plt.show()

# %%
X_test.hist(bins=50, figsize=(10,10))
plt.show()

# %%
y_train.hist()
# Out:
# <AxesSubplot:>

# %%
y_test.hist()
# Out:
# <AxesSubplot:>

# %%
listings.isna().sum().sort_values(ascending = False)
# Out:
# review_scores_accuracy              823
# review_scores_location              822
# review_scores_value                 821
# review_scores_checkin               820
# review_scores_cleanliness           818
# review_scores_communication         818
# review_scores_rating                813
# reviews_per_month                   756
# host_acceptance_rate                471
# host_response_rate                  471
# host_response_time                  471
# host_neighbourhood                  339
# bathrooms                            14
# bedrooms                             10
# beds                                  9
# property_type                         3
# city                                  2
# id                                    0
# instant_bookable                      0
# number_of_reviews                     0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# days_operation                        0
# cancellation_policy                   0
# bed_type                              0
# minimum_nights                        0
# cleaning_fee                          0
# security_deposit                      0
# amenities                             0
# host_location                         0
# room_type                             0
# is_location_exact                     0
# longitude                             0
# latitude                              0
# smart_location                        0
# neighbourhood_cleansed                0
# host_identity_verified                0
# host_verifications                    0
# host_total_listings_count             0
# host_is_superhost                     0
# price_per_person                      0
# dtype: int64

# %%
X_train['review_scores_accuracy'].mean()
# Out:
# 9.431230610134437

# %%
#We will use missing value for the review columns NAs, since the proportion of the missing data is huge - 20% of the total dataset
missing_value = ['reviews_per_month','review_scores_location',
                          'review_scores_value','review_scores_checkin','review_scores_cleanliness',
                          'review_scores_communication','review_scores_rating','review_scores_accuracy',
                'host_response_time']

for col in missing_value:
    X_train[col].fillna(-1,inplace=True)
    X_test[col].fillna(-1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
# Imputing with median value - Based on the nature of the variables, as well as on their distribution, we are choosing what to impute with: variables with more close to normal distribution - mean; skewed variables - median
numeric_features_median = ['bathrooms','bedrooms','beds','days_operation','host_response_rate','host_acceptance_rate']

for col in numeric_features_median:
    X_train[col].fillna(X_train[col].median(),inplace=True)
    X_test[col].fillna(X_test[col].median(),inplace=True)

# %%
X_train['host_response_time'].mode().values[0]
# Out:
# 'within an hour'

# %%
#impute with mode for the categorical features
cat_features_mode = ['host_neighbourhood','property_type','city']

for col in cat_features_mode:
    most = X_train[col].mode().values[0]
    X_train[col].fillna(most,inplace=True)
    most2 = X_test[col].mode().values[0]
    X_test[col].fillna(most2,inplace=True)

# %%
X_train.isna().sum().sort_values(ascending=False)
# Out:
# id                                  0
# bed_type                            0
# security_deposit                    0
# cleaning_fee                        0
# minimum_nights                      0
# number_of_reviews                   0
# review_scores_rating                0
# review_scores_accuracy              0
# review_scores_cleanliness           0
# review_scores_checkin               0
# review_scores_communication         0
# review_scores_location              0
# review_scores_value                 0
# instant_bookable                    0
# cancellation_policy                 0
# require_guest_profile_picture       0
# require_guest_phone_verification    0
# calculated_host_listings_count      0
# reviews_per_month                   0
# amenities                           0
# beds                                0
# host_location                       0
# bedrooms                            0
# host_response_time                  0
# host_response_rate                  0
# host_acceptance_rate                0
# host_is_superhost                   0
# host_neighbourhood                  0
# host_total_listings_count           0
# host_verifications                  0
# host_identity_verified              0
# neighbourhood_cleansed              0
# city                                0
# smart_location                      0
# latitude                            0
# longitude                           0
# is_location_exact                   0
# property_type                       0
# room_type                           0
# bathrooms                           0
# days_operation                      0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# host_response_time                  0
# host_response_rate                  0
# host_acceptance_rate                0
# host_is_superhost                   0
# host_neighbourhood                  0
# host_total_listings_count           0
# host_identity_verified              0
# neighbourhood_cleansed              0
# city                                0
# smart_location                      0
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# bathrooms                           0
# bedrooms                            0
# beds                                0
# bed_type                            0
# amenities                           0
# security_deposit                    0
# cleaning_fee                        0
# minimum_nights                      0
# number_of_reviews                   0
# review_scores_rating                0
# review_scores_accuracy              0
# review_scores_cleanliness           0
# review_scores_checkin               0
# review_scores_communication         0
# review_scores_location              0
# review_scores_value                 0
# instant_bookable                    0
# cancellation_policy                 0
# require_guest_profile_picture       0
# require_guest_phone_verification    0
# reviews_per_month                   0
# days_operation                      0
# dtype: int64

# %%
X_test.head()
# Out:
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 3163      within an hour               100.0                 100.0
# 3133  within a few hours               100.0                  80.0
# 937       within an hour               100.0                 100.0
# 196       within an hour               100.0                 100.0
# 2852        within a day               100.0                 100.0
#
#       host_is_superhost host_neighbourhood  host_total_listings_count  \
# 3163                  0       South Boston                          1
# 3133                  1       South Boston                          1
# 937                   0          South End                          4
# 196                   1      Jamaica Plain                          2
# 2852                  0           Mattapan                          0
#
#       host_identity_verified neighbourhood_cleansed    city smart_location  \
# 3163                       0           South Boston  Boston     Boston, MA
# 3133                       1           South Boston  Boston     Boston, MA
# 937                        1              South End  Boston     Boston, MA
# 196                        1          Jamaica Plain  Boston     Boston, MA
# 2852                       0             Dorchester  Boston     Boston, MA
#
#        latitude  longitude property_type        room_type  bathrooms  \
# 3163  42.336777 -71.038163     Apartment  Entire home/apt        1.0
# 3133  42.336180 -71.027815     Apartment     Private room        1.0
# 937   42.345039 -71.062135     Apartment  Entire home/apt        2.0
# 196   42.319620 -71.104829     Apartment  Entire home/apt        1.0
# 2852  42.297679 -71.080782         House     Private room        1.0
#
#       bedrooms  beds  bed_type  \
# 3163       1.0   1.0  Real Bed
# 3133       1.0   1.0  Real Bed
# 937        3.0   4.0  Real Bed
# 196        1.0   2.0  Real Bed
# 2852       1.0   1.0  Real Bed
#
#                                               amenities  security_deposit  \
# 3163  {TV,"Wireless Internet","Air Conditioning",Kit...             100.0
# 3133  {TV,"Wireless Internet","Air Conditioning",Kit...               0.0
# 937   {TV,"Wireless Internet","Air Conditioning",Poo...             500.0
# 196   {TV,Internet,"Wireless Internet","Air Conditio...             200.0
# 2852  {"Wireless Internet","Family/Kid Friendly","Sm...               0.0
#
#       cleaning_fee  minimum_nights  number_of_reviews  review_scores_rating  \
# 3163          30.0               1                 10                  96.0
# 3133          45.0               1                 26                  96.0
# 937          150.0               2                  1                  80.0
# 196           45.0               2                127                  97.0
# 2852          25.0               3                  0                  -1.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 3163                    10.0                       10.0
# 3133                    10.0                       10.0
# 937                     10.0                       10.0
# 196                     10.0                       10.0
# 2852                    -1.0                       -1.0
#
#       review_scores_checkin  review_scores_communication  \
# 3163                    9.0                          9.0
# 3133                   10.0                         10.0
# 937                     8.0                          8.0
# 196                    10.0                         10.0
# 2852                   -1.0                         -1.0
#
#       review_scores_location  review_scores_value  instant_bookable  \
# 3163                    10.0                 10.0                 0
# 3133                    10.0                  9.0                 0
# 937                      8.0                  8.0                 1
# 196                     10.0                 10.0                 1
# 2852                    -1.0                 -1.0                 0
#
#      cancellation_policy  require_guest_profile_picture  \
# 3163            moderate                              0
# 3133            moderate                              0
# 937               strict                              0
# 196               strict                              0
# 2852            moderate                              0
#
#       require_guest_phone_verification  reviews_per_month  days_operation
# 3163                                 0               0.55             617
# 3133                                 0               1.54             559
# 937                                  0               1.00            1230
# 196                                  0               5.08             784
# 2852                                 0              -1.00             993

# %%
y_train.head()
# Out:
# 2609    65.38
# 2014    45.80
# 407     20.67
# 1188    66.67
# 1084    45.67
# Name: price_per_person, dtype: float64

# %%
#In addition, we will drop the id, the host_id
X_train.drop(['id'],axis=1,inplace=True)
X_test.drop(['id'],axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
X_train.describe().transpose()
# Out:
#                                    count        mean         std        min  \
# host_response_rate                2509.0   95.430450   12.279979   0.000000
# host_acceptance_rate              2509.0   85.508569   20.432632   0.000000
# host_is_superhost                 2509.0    0.118374    0.323115   0.000000
# host_total_listings_count         2509.0   58.889996  170.648759   0.000000
# host_identity_verified            2509.0    0.729773    0.444166   0.000000
# latitude                          2509.0   42.340250    0.024402  42.235942
# longitude                         2509.0  -71.084777    0.031646 -71.171789
# bathrooms                         2509.0    1.226983    0.509277   0.000000
# bedrooms                          2509.0    1.256676    0.751580   0.000000
# beds                              2509.0    1.604623    1.024381   0.000000
# security_deposit                  2509.0  124.251893  262.327150   0.000000
# cleaning_fee                      2509.0   47.479075   53.801032   0.000000
# minimum_nights                    2509.0    3.126345    7.454619   1.000000
# number_of_reviews                 2509.0   18.989239   35.007511   0.000000
# review_scores_rating              2509.0   71.050618   39.751303  -1.000000
# review_scores_accuracy            2509.0    7.040654    4.461686  -1.000000
# review_scores_cleanliness         2509.0    6.944201    4.419680  -1.000000
# review_scores_checkin             2509.0    7.223196    4.518746  -1.000000
# review_scores_communication       2509.0    7.226784    4.513137  -1.000000
# review_scores_location            2509.0    7.047031    4.451334  -1.000000
# review_scores_value               2509.0    6.858111    4.368561  -1.000000
# instant_bookable                  2509.0    0.166600    0.372693   0.000000
# require_guest_profile_picture     2509.0    0.017138    0.129813   0.000000
# require_guest_phone_verification  2509.0    0.063372    0.243679   0.000000
# reviews_per_month                 2509.0    1.359454    2.270770  -1.000000
# days_operation                    2509.0  897.855321  624.140339   1.000000
#
#                                          25%         50%          75%  \
# host_response_rate                 98.000000  100.000000   100.000000
# host_acceptance_rate               78.000000   94.000000   100.000000
# host_is_superhost                   0.000000    0.000000     0.000000
# host_total_listings_count           1.000000    2.000000     7.000000
# host_identity_verified              0.000000    1.000000     1.000000
# latitude                           42.330082   42.345393    42.354910
# longitude                         -71.104937  -71.078077   -71.061995
# bathrooms                           1.000000    1.000000     1.000000
# bedrooms                            1.000000    1.000000     2.000000
# beds                                1.000000    1.000000     2.000000
# security_deposit                    0.000000    0.000000   199.000000
# cleaning_fee                        0.000000   30.000000    80.000000
# minimum_nights                      1.000000    2.000000     3.000000
# number_of_reviews                   1.000000    5.000000    21.000000
# review_scores_rating               70.000000   92.000000    97.000000
# review_scores_accuracy              7.000000    9.000000    10.000000
# review_scores_cleanliness           6.000000    9.000000    10.000000
# review_scores_checkin               8.000000   10.000000    10.000000
# review_scores_communication         8.000000   10.000000    10.000000
# review_scores_location              8.000000    9.000000    10.000000
# review_scores_value                 7.000000    9.000000    10.000000
# instant_bookable                    0.000000    0.000000     0.000000
# require_guest_profile_picture       0.000000    0.000000     0.000000
# require_guest_phone_verification    0.000000    0.000000     0.000000
# reviews_per_month                   0.120000    0.780000     2.160000
# days_operation                    443.000000  765.000000  1262.000000
#
#                                           max
# host_response_rate                 100.000000
# host_acceptance_rate               100.000000
# host_is_superhost                    1.000000
# host_total_listings_count          749.000000
# host_identity_verified               1.000000
# latitude                            42.389982
# longitude                          -71.000100
# bathrooms                            6.000000
# bedrooms                             5.000000
# beds                                16.000000
# security_deposit                  4500.000000
# cleaning_fee                       300.000000
# minimum_nights                     273.000000
# number_of_reviews                  312.000000
# review_scores_rating               100.000000
# review_scores_accuracy              10.000000
# review_scores_cleanliness           10.000000
# review_scores_checkin               10.000000
# review_scores_communication         10.000000
# review_scores_location              10.000000
# review_scores_value                 10.000000
# instant_bookable                     1.000000
# require_guest_profile_picture        1.000000
# require_guest_phone_verification     1.000000
# reviews_per_month                   19.150000
# days_operation                    2857.000000

# %%
X_test.describe().transpose()
# Out:
#                                    count        mean         std        min  \
# host_response_rate                1076.0   96.153346   10.541687   0.000000
# host_acceptance_rate              1076.0   85.360595   20.887920   0.000000
# host_is_superhost                 1076.0    0.102230    0.303092   0.000000
# host_total_listings_count         1076.0   58.931227  172.292350   0.000000
# host_identity_verified            1076.0    0.717472    0.450438   0.000000
# latitude                          1076.0   42.339522    0.024408  42.244682
# longitude                         1076.0  -71.084912    0.031389 -71.169953
# bathrooms                         1076.0    1.206320    0.480016   0.000000
# bedrooms                          1076.0    1.251859    0.753748   0.000000
# beds                              1076.0    1.614312    0.979292   0.000000
# security_deposit                  1076.0  115.238848  238.036385   0.000000
# cleaning_fee                      1076.0   46.766729   51.363370   0.000000
# minimum_nights                    1076.0    3.276022   11.527561   1.000000
# number_of_reviews                 1076.0   19.173792   36.869910   0.000000
# review_scores_rating              1076.0   70.366171   39.949034  -1.000000
# review_scores_accuracy            1076.0    7.027881    4.468928  -1.000000
# review_scores_cleanliness         1076.0    6.855019    4.442855  -1.000000
# review_scores_checkin             1076.0    7.183086    4.531947  -1.000000
# review_scores_communication       1076.0    7.195167    4.521269  -1.000000
# review_scores_location            1076.0    6.977695    4.447467  -1.000000
# review_scores_value               1076.0    6.796468    4.356703  -1.000000
# instant_bookable                  1076.0    0.163569    0.370056   0.000000
# require_guest_profile_picture     1076.0    0.022305    0.147742   0.000000
# require_guest_phone_verification  1076.0    0.072491    0.259419   0.000000
# reviews_per_month                 1076.0    1.309322    2.167051  -1.000000
# days_operation                    1076.0  887.236989  613.107999   1.000000
#
#                                          25%         50%          75%  \
# host_response_rate                 98.000000  100.000000   100.000000
# host_acceptance_rate               79.000000   94.000000   100.000000
# host_is_superhost                   0.000000    0.000000     0.000000
# host_total_listings_count           1.000000    2.000000     7.000000
# host_identity_verified              0.000000    1.000000     1.000000
# latitude                           42.329343   42.344739    42.353722
# longitude                         -71.105606  -71.079460   -71.062774
# bathrooms                           1.000000    1.000000     1.000000
# bedrooms                            1.000000    1.000000     2.000000
# beds                                1.000000    1.000000     2.000000
# security_deposit                    0.000000    0.000000   150.000000
# cleaning_fee                        0.000000   30.000000    80.000000
# minimum_nights                      1.000000    2.000000     3.000000
# number_of_reviews                   1.000000    5.000000    21.000000
# review_scores_rating               64.000000   91.000000    97.000000
# review_scores_accuracy              7.000000    9.000000    10.000000
# review_scores_cleanliness           6.000000    9.000000    10.000000
# review_scores_checkin               8.000000   10.000000    10.000000
# review_scores_communication         8.000000   10.000000    10.000000
# review_scores_location              7.000000    9.000000    10.000000
# review_scores_value                 7.000000    9.000000    10.000000
# instant_bookable                    0.000000    0.000000     0.000000
# require_guest_profile_picture       0.000000    0.000000     0.000000
# require_guest_phone_verification    0.000000    0.000000     0.000000
# reviews_per_month                   0.110000    0.775000     2.062500
# days_operation                    446.250000  768.500000  1189.250000
#
#                                           max
# host_response_rate                 100.000000
# host_acceptance_rate               100.000000
# host_is_superhost                    1.000000
# host_total_listings_count          749.000000
# host_identity_verified               1.000000
# latitude                            42.389682
# longitude                          -71.000261
# bathrooms                            6.000000
# bedrooms                             5.000000
# beds                                 9.000000
# security_deposit                  3000.000000
# cleaning_fee                       300.000000
# minimum_nights                     300.000000
# number_of_reviews                  404.000000
# review_scores_rating               100.000000
# review_scores_accuracy              10.000000
# review_scores_cleanliness           10.000000
# review_scores_checkin               10.000000
# review_scores_communication         10.000000
# review_scores_location              10.000000
# review_scores_value                 10.000000
# instant_bookable                     1.000000
# require_guest_profile_picture        1.000000
# require_guest_phone_verification     1.000000
# reviews_per_month                   12.950000
# days_operation                    2857.000000

# %%
X_train.describe(include='object').transpose()
# Out:
#                        count unique               top  freq
# host_response_time      2509      5    within an hour   961
# host_neighbourhood      2509     47  Allston-Brighton   492
# neighbourhood_cleansed  2509     25     Jamaica Plain   225
# city                    2509     34            Boston  2369
# smart_location          2509     35        Boston, MA  2367
# property_type           2509     11         Apartment  1844
# room_type               2509      3   Entire home/apt  1479
# bed_type                2509      5          Real Bed  2410
# amenities               2509   2213                {}    27
# cancellation_policy     2509      4            strict  1114

# %%
X_train.shape
# Out:
# (2509, 36)

# %%
X_test.shape
# Out:
# (1076, 36)

# %%
X_train.drop(['host_location',
             'is_location_exact','calculated_host_listings_count','host_verifications'],axis=1,inplace=True)
X_test.drop(['host_location',
              'is_location_exact','calculated_host_listings_count','host_verifications'],axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# # 3. Other feature engineering
# - cardinality check
# - categorical encoding
# - discretization

# %% [markdown]
# ### 3.1. Cardinality check
# on columns: host_response_time, host_neighbourhood, host_verifications, neighbourhood_cleansed,city,smart_location,property type, room type, bed type, amenities, cancellation policy<br>
#
# host_response_rate, neighbourhood_cleansed, property_type, room_type, bed_type, cancellation_policy - to be encoded<br>
# city - encoded as Binary; smart_location - stores the same info as city, dropped<br>
# host_neighbourhood - transform into another variable: 1 if it is the same with the listing neighbourhood, 0 if it is different<br>
# __amenities & host_verifications - text preprocessing&feature vectorization

# %%
X_train['host_response_time'].value_counts()
# Out:
# within an hour        961
# within a few hours    867
# within a day          328
# -1                    317
# a few days or more     36
# Name: host_response_time, dtype: int64

# %%
X_train['smart_location'].value_counts()
# Out:
# Boston, MA                       2367
# Roxbury Crossing, MA               16
# Brookline, MA                      13
# Jamaica Plain, MA                  12
# Somerville, MA                     11
# Brighton, MA                       11
# Dorchester, MA                     11
# Cambridge, MA                      11
# Charlestown, MA                    10
# Allston, MA                         9
# Roslindale, MA                      4
# East Boston, MA                     3
# Mattapan, MA                        3
# MA                                  2
# Boston, Massachusetts, US, MA       2
# ROXBURY CROSSING, MA                2
# West Roxbury, MA                    2
# Jamaica Plain , MA                  2
# ALLSTON, MA                         2
# Mission Hill, Boston, MA            1
# South Boston, MA                    1
# Roslindale, Boston, MA              1
# Brighton , MA                       1
# dorchester, boston , MA             1
# Jamaica Plain, Boston, MA           1
# east Boston , MA                    1
# Jamaica Plain (Boston), MA          1
# Boston (Jamaica Plain), MA          1
# Jamaica plain , MA                  1
# Watertown, MA                       1
# Newton, MA                          1
# boston, MA                          1
# Hyde Park, MA                       1
# Boston , MA                         1
# Jamaica Plain, MA, MA               1
# Name: smart_location, dtype: int64

# %%
X_train['host_response_rate'].isna().sum()
# Out:
# 0

# %%
X_test['host_response_rate'].value_counts()
# Out:
# 100.0    778
# 98.0      57
# 90.0      30
# 89.0      27
# 96.0      26
# 71.0      19
# 99.0      17
# 92.0      12
# 80.0      10
# 97.0       9
# 94.0       7
# 95.0       7
# 50.0       6
# 79.0       6
# 77.0       5
# 60.0       5
# 85.0       5
# 75.0       5
# 78.0       4
# 70.0       4
# 67.0       4
# 81.0       4
# 91.0       3
# 0.0        3
# 88.0       3
# 73.0       3
# 83.0       3
# 86.0       3
# 93.0       2
# 82.0       2
# 69.0       2
# 14.0       1
# 61.0       1
# 33.0       1
# 6.0        1
# 36.0       1
# Name: host_response_rate, dtype: int64

# %%
#THe prevailing value was Boston, so we marked the city with 1 for Boston, and 0 for the rest
X_train['city']=np.where(X_train['city']=='Boston',1,0)
X_test['city']=np.where(X_test['city']=='Boston',1,0)
# Out:
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/1657766666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['city']=np.where(X_train['city']=='Boston',1,0)
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/1657766666.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['city']=np.where(X_test['city']=='Boston',1,0)

# %%
#drop smart location, as it is the same as City
X_train.drop(['smart_location'],axis=1,inplace=True)
X_test.drop(['smart_location'],axis=1,inplace=True)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#For the host neighbourhoud, I will introduce a new variable - whether it is the same as the property neighbourhood. 
X_train['same_neigh'] = np.where(X_train['host_neighbourhood'].str.lower() == X_train['neighbourhood_cleansed'].str.lower(), 1, 0)
# Out:
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/1459199661.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['same_neigh'] = np.where(X_train['host_neighbourhood'].str.lower() == X_train['neighbourhood_cleansed'].str.lower(), 1, 0)

# %%
X_test['same_neigh'] = np.where(X_test['host_neighbourhood'].str.lower() == X_test['neighbourhood_cleansed'].str.lower(), 1, 0)
# Out:
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/593835809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['same_neigh'] = np.where(X_test['host_neighbourhood'].str.lower() == X_test['neighbourhood_cleansed'].str.lower(), 1, 0)

# %%
X_train.drop(['host_neighbourhood'],axis=1,inplace=True)
X_test.drop(['host_neighbourhood'],axis=1,inplace=True)

# %%
X_train['neighbourhood_cleansed'].value_counts()
# Out:
# Jamaica Plain              225
# South End                  223
# Back Bay                   222
# Fenway                     208
# Dorchester                 194
# Allston                    186
# Beacon Hill                136
# Downtown                   130
# Brighton                   129
# South Boston               122
# North End                  103
# East Boston                100
# Roxbury                     99
# Mission Hill                82
# Charlestown                 74
# South Boston Waterfront     59
# Chinatown                   46
# West End                    38
# Roslindale                  37
# West Roxbury                34
# Hyde Park                   23
# Mattapan                    15
# Bay Village                 14
# Longwood Medical Area        7
# Leather District             3
# Name: neighbourhood_cleansed, dtype: int64

# %%
X_train['amenities'].nunique()
# Out:
# 2213

# %%
#X_train['host_verifications'].nunique()

# %%
listings['property_type'].value_counts()
# Out:
# Apartment          2612
# House               562
# Condominium         231
# Townhouse            54
# Bed & Breakfast      41
# Loft                 39
# Other                17
# Boat                 12
# Villa                 6
# Entire Floor          4
# Dorm                  2
# Guesthouse            1
# Camper/RV             1
# Name: property_type, dtype: int64

# %% [markdown]
# #### 3.1.1.Categorical handling of host verifications and amenities

# %%
def text_cleaner_open_amenities(serie, words= []):
    '''
    input: pandas series, stop words
    ouput: removes special char, stop words, symbols.'''
    serie = serie.astype(str).str.lower()
    #st = PorterStemmer()
    stop= stopwords.words('english') + words
    stop = [x for x in stop]
    
    serie=serie.str.replace('"','')
    serie=serie.str.replace('{','')
    serie=serie.str.replace('}','')
    serie= serie.apply(lambda x: " ".join([word for word in x.split() 
                                           if word not in stop])) 
    return serie

# %%
X_train['amenities'] = text_cleaner_open_amenities(X_train['amenities'])
X_test['amenities'] = text_cleaner_open_amenities(X_test['amenities'])
# Out:
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/4007061188.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   serie=serie.str.replace('{','')
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/4007061188.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   serie=serie.str.replace('}','')
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/4267831456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['amenities'] = text_cleaner_open_amenities(X_train['amenities'])
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/4267831456.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['amenities'] = text_cleaner_open_amenities(X_test['amenities'])

# %%
vectorizer_am = CountVectorizer(tokenizer=lambda x: x.split(','))
vectorizer_am.fit(X_train['amenities'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:489: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# CountVectorizer(tokenizer=<function <lambda> at 0x7fedd19fe3a0>)

# %%
vectorizer_am.get_feature_names()
# Out:
# ['',
#  '24-hour check-in',
#  'air conditioning',
#  'breakfast',
#  'buzzer/wireless intercom',
#  'cable tv',
#  'carbon monoxide detector',
#  'cat(s)',
#  'dog(s)',
#  'doorman',
#  'dryer',
#  'elevator building',
#  'essentials',
#  'family/kid friendly',
#  'fire extinguisher',
#  'first aid kit',
#  'free parking premises',
#  'free parking street',
#  'gym',
#  'hair dryer',
#  'hangers',
#  'heating',
#  'hot tub',
#  'indoor fireplace',
#  'internet',
#  'iron',
#  'kitchen',
#  'laptop friendly workspace',
#  'lock bedroom door',
#  'other pet(s)',
#  'paid parking premises',
#  'pets allowed',
#  'pets live property',
#  'pool',
#  'safety card',
#  'shampoo',
#  'smoke detector',
#  'smoking allowed',
#  'suitable events',
#  'translation missing: en.hosting_amenity_49',
#  'translation missing: en.hosting_amenity_50',
#  'tv',
#  'washer',
#  'washer / dryer',
#  'wheelchair accessible',
#  'wireless internet']

# %%
dt = vectorizer_am.transform(X_train['amenities'])

# %%
dt.shape
# Out:
# (2509, 46)

# %%
#new = pd.DataFrame(dt.toarray(), columns=vectorizer_am.get_feature_names(), index= a.index)

# %%
#new.isna().sum()

# %%
X_train = X_train.join(pd.DataFrame(dt.toarray(), columns=vectorizer_am.get_feature_names(), index= X_train.index))

# %%
X_train.shape
# Out:
# (2509, 81)

# %%
X_train.head()
# Out:
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 2609  within a few hours               100.0                  80.0
# 2014        within a day                98.0                  68.0
# 407         within a day               100.0                 100.0
# 1188      within an hour               100.0                  43.0
# 1084  within a few hours               100.0                  91.0
#
#       host_is_superhost  host_total_listings_count  host_identity_verified  \
# 2609                  0                          1                       0
# 2014                  0                         24                       1
# 407                   0                          1                       0
# 1188                  0                          1                       1
# 1084                  0                         52                       1
#
#      neighbourhood_cleansed  city   latitude  longitude property_type  \
# 2609               Brighton     1  42.337190 -71.151437   Condominium
# 2014            Beacon Hill     1  42.357559 -71.071720     Apartment
# 407            Mission Hill     1  42.328580 -71.098055     Apartment
# 1188              South End     1  42.344141 -71.072263     Apartment
# 1084              South End     1  42.345003 -71.077470     Apartment
#
#             room_type  bathrooms  bedrooms  beds  bed_type  \
# 2609  Entire home/apt        1.0       1.0   3.0     Futon
# 2014  Entire home/apt        1.0       1.0   1.0  Real Bed
# 407      Private room        2.0       1.0   1.0  Real Bed
# 1188  Entire home/apt        1.0       2.0   1.0  Real Bed
# 1084  Entire home/apt        1.0       0.0   1.0  Real Bed
#
#                                               amenities  security_deposit  \
# 2609  internet,wireless internet,air conditioning,ki...               0.0
# 2014  tv,cable tv,internet,wireless internet,air con...             500.0
# 407   tv,cable tv,internet,wireless internet,air con...               0.0
# 1188  tv,cable tv,internet,wireless internet,air con...             250.0
# 1084  tv,cable tv,wireless internet,air conditioning...               0.0
#
#       cleaning_fee  minimum_nights  number_of_reviews  review_scores_rating  \
# 2609          30.0               1                 16                  89.0
# 2014         100.0               2                  9                  89.0
# 407           35.0               1                  0                  -1.0
# 1188          65.0               1                  6                 100.0
# 1084         225.0               7                  0                  -1.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 2609                     8.0                        9.0
# 2014                    10.0                        9.0
# 407                     -1.0                       -1.0
# 1188                    10.0                       10.0
# 1084                    -1.0                       -1.0
#
#       review_scores_checkin  review_scores_communication  \
# 2609                   10.0                         10.0
# 2014                    9.0                          9.0
# 407                    -1.0                         -1.0
# 1188                   10.0                         10.0
# 1084                   -1.0                         -1.0
#
#       review_scores_location  review_scores_value  instant_bookable  \
# 2609                     9.0                  9.0                 0
# 2014                    10.0                  9.0                 0
# 407                     -1.0                 -1.0                 0
# 1188                    10.0                 10.0                 0
# 1084                    -1.0                 -1.0                 0
#
#      cancellation_policy  require_guest_profile_picture  \
# 2609            moderate                              1
# 2014              strict                              0
# 407               strict                              0
# 1188              strict                              0
# 1084              strict                              0
#
#       require_guest_phone_verification  reviews_per_month  days_operation  \
# 2609                                 1               0.40            1206
# 2014                                 0               0.92            1747
# 407                                  0              -1.00             798
# 1188                                 0               0.37             549
# 1084                                 0              -1.00             699
#
#       same_neigh     24-hour check-in  air conditioning  breakfast  \
# 2609           0  0                 1                 1          0
# 2014           0  0                 0                 1          0
# 407            1  0                 0                 1          0
# 1188           1  0                 0                 1          0
# 1084           0  0                 0                 1          0
#
#       buzzer/wireless intercom  cable tv  carbon monoxide detector  cat(s)  \
# 2609                         1         0                         1       0
# 2014                         0         1                         1       0
# 407                          1         1                         0       0
# 1188                         1         1                         0       0
# 1084                         0         1                         0       0
#
#       dog(s)  doorman  dryer  elevator building  essentials  \
# 2609       0        0      0                  0           1
# 2014       0        0      1                  1           0
# 407        0        0      1                  0           1
# 1188       0        0      1                  0           1
# 1084       0        0      1                  0           0
#
#       family/kid friendly  fire extinguisher  first aid kit  \
# 2609                    1                  0              0
# 2014                    1                  1              0
# 407                     0                  1              0
# 1188                    0                  0              0
# 1084                    0                  0              0
#
#       free parking premises  free parking street  gym  hair dryer  hangers  \
# 2609                      1                    0    0           1        1
# 2014                      0                    0    0           1        0
# 407                       0                    0    0           0        1
# 1188                      0                    0    0           0        0
# 1084                      0                    0    0           0        0
#
#       heating  hot tub  indoor fireplace  internet  iron  kitchen  \
# 2609        1        0                 0         1     1        1
# 2014        1        0                 0         1     1        1
# 407         1        0                 0         1     1        1
# 1188        1        0                 0         1     0        1
# 1084        1        0                 0         0     0        1
#
#       laptop friendly workspace  lock bedroom door  other pet(s)  \
# 2609                          1                  0             0
# 2014                          0                  0             0
# 407                           0                  0             0
# 1188                          0                  0             0
# 1084                          0                  0             0
#
#       paid parking premises  pets allowed  pets live property  pool  \
# 2609                      0             0                   0     0
# 2014                      0             0                   0     0
# 407                       0             0                   0     0
# 1188                      0             0                   0     0
# 1084                      0             0                   0     0
#
#       safety card  shampoo  smoke detector  smoking allowed  suitable events  \
# 2609            0        1               1                0                0
# 2014            0        0               1                0                0
# 407             0        0               1                0                0
# 1188            0        1               1                0                0
# 1084            0        0               0                0                0
#
#       translation missing: en.hosting_amenity_49  \
# 2609                                           0
# 2014                                           0
# 407                                            0
# 1188                                           0
# 1084                                           1
#
#       translation missing: en.hosting_amenity_50  tv  washer  washer / dryer  \
# 2609                                           0   0       0               0
# 2014                                           0   1       1               0
# 407                                            0   1       1               0
# 1188                                           0   1       1               0
# 1084                                           1   1       1               0
#
#       wheelchair accessible  wireless internet
# 2609                      0                  1
# 2014                      0                  1
# 407                       0                  1
# 1188                      0                  1
# 1084                      0                  1

# %%
dt1 = vectorizer_am.transform(X_test['amenities'])

# %%
dt1.shape
# Out:
# (1076, 46)

# %%
X_test = X_test.join(pd.DataFrame(dt1.toarray(), columns=vectorizer_am.get_feature_names(), index= X_test.index))

# %%
#combine some of the features
X_train.loc[X_train['wireless internet']==1,'internet']=1
X_test.loc[X_test['wireless internet']==1,'internet']=1

# %%
X_train.loc[X_train['tv']==1,'cable tv']=1
X_test.loc[X_test['tv']==1,'cable tv']=1

# %%
X_train.loc[X_train['washer / dryer']==1,'washer']=1
X_train.loc[X_train['washer / dryer']==1,'dryer']=1

X_test.loc[X_test['washer / dryer']==1,'washer']=1
X_test.loc[X_test['washer / dryer']==1,'dryer']=1

# %%
X_train.drop(['','translation missing: en.hosting_amenity_49',
 'translation missing: en.hosting_amenity_50','wireless internet','tv','washer / dryer'],axis=1,inplace=True)

# %%
X_test.drop(['','translation missing: en.hosting_amenity_49',
 'translation missing: en.hosting_amenity_50','wireless internet','tv','washer / dryer'],axis=1,inplace=True)

# %%
X_train.shape
# Out:
# (2509, 75)

# %%
X_test.shape
# Out:
# (1076, 75)

# %% [markdown]
# #### 3.1.2.Host verifications

# %%
def text_cleaner_open_verifications(serie, words= []):
    '''
    input: pandas series, stop words
    ouput: removes special char, stop words, symbols.'''
    serie = serie.astype(str).str.lower()
    #st = PorterStemmer()
    stop= stopwords.words('english') + words
    stop = [x for x in stop]
    
    serie=serie.str.replace('\'','')
    serie=serie.str.replace('{','')
    serie=serie.str.replace('}','')
    serie=serie.str.replace('[','')
    serie=serie.str.replace(']','')
    serie = serie.str.strip()
    serie= serie.apply(lambda x: " ".join([word for word in x.split() 
                                           if word not in stop])) 
    return serie

# %%
X_train['host_verifications'] = text_cleaner_open_verifications(X_train['host_verifications'])
X_test['host_verifications'] = text_cleaner_open_verifications(X_test['host_verifications'])
# Out:
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_1858/2348857406.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   serie=serie.str.replace('{','')
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_1858/2348857406.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   serie=serie.str.replace('}','')
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_1858/2348857406.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   serie=serie.str.replace('[','')
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_1858/2348857406.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   serie=serie.str.replace(']','')

# %%
vectorizer = CountVectorizer(tokenizer=lambda x: x.split(','))
vectorizer.fit(X_train['host_verifications'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:489: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# CountVectorizer(tokenizer=<function <lambda> at 0x7f83291483a0>)

# %%
vectorizer.get_feature_names()
# Out:
# [' amex',
#  ' facebook',
#  ' google',
#  ' jumio',
#  ' kba',
#  ' linkedin',
#  ' manual_offline',
#  ' manual_online',
#  ' phone',
#  ' reviews',
#  ' sent_id',
#  ' weibo',
#  'email',
#  'phone']

# %%
dt2 = vectorizer.transform(X_train['host_verifications'])

# %%
dt2.shape
# Out:
# (2509, 14)

# %%
X_train = X_train.join(pd.DataFrame(dt2.toarray(), columns=vectorizer.get_feature_names(), index= X_train.index))

# %%
dt3 = vectorizer.transform(X_test['host_verifications'])

# %%
dt3.shape
# Out:
# (1076, 14)

# %%
X_test = X_test.join(pd.DataFrame(dt3.toarray(), columns=vectorizer.get_feature_names(), index= X_test.index))

# %%
X_test.shape
# Out:
# (1076, 93)

# %%
X_train.loc[X_train[' phone']==1,'phone']=1
X_test.loc[X_test[' phone']==1,'phone']=1

# %%
X_train.drop(['phone'],axis=1,inplace=True)
X_test.drop(['phone'],axis=1,inplace=True)

# %%
X_train.drop(['amenities','host_verifications'],axis=1,inplace=True)
X_test.drop(['amenities','host_verifications'],axis=1,inplace=True)

# %%
X_train.shape
# Out:
# (2509, 75)

# %%
X_test.shape
# Out:
# (1076, 75)

# %%
X_train_t=X_train.copy()
X_test_t=X_test.copy()

# %% [markdown]
# ### 3.2. Categorical encoding
# For this I will use one-hot encoding.
# __For Linear regression model - encode into K-1 variables<br>
# For tree models - encode into K variables, since with the ensemble methods we are not using all features__
# I am using the One-hot encoder from the feature engine, since it directly returns a dataframe w/o the original variable, with the respective names etc.

# %%
X_train.describe(include='object').transpose()
# Out:
#                        count unique              top  freq
# host_response_time      2509      5   within an hour   961
# neighbourhood_cleansed  2509     25    Jamaica Plain   225
# property_type           2509     11        Apartment  1844
# room_type               2509      3  Entire home/apt  1479
# bed_type                2509      5         Real Bed  2410
# amenities               2509   2213                     27
# cancellation_policy     2509      4           strict  1114

# %%
X_test.isna().sum().sort_values(ascending=False).head()
# Out:
# host_response_time    0
# hot tub               0
# hangers               0
# hair dryer            0
# gym                   0
# dtype: int64

# %%
ohe_enc = fe_OneHotEncoder(
    top_categories=None,
    variables=['host_response_time','neighbourhood_cleansed','property_type','room_type','bed_type','cancellation_policy'],  # we can select which variables to encode
    drop_last=False)  # to return k-1, false to return k

ohe_enc.fit(X_train)
# Out:
# OneHotEncoder(variables=['host_response_time', 'neighbourhood_cleansed',
#                          'property_type', 'room_type', 'bed_type',
#                          'cancellation_policy'])

# %%
X_train_tr = ohe_enc.transform(X_train)

X_train_tr.head()
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 2609               100.0                  80.0                  0
# 2014                98.0                  68.0                  0
# 407                100.0                 100.0                  0
# 1188               100.0                  43.0                  0
# 1084               100.0                  91.0                  0
#
#       host_total_listings_count  host_identity_verified  city   latitude  \
# 2609                          1                       0     1  42.337190
# 2014                         24                       1     1  42.357559
# 407                           1                       0     1  42.328580
# 1188                          1                       1     1  42.344141
# 1084                         52                       1     1  42.345003
#
#       longitude  bathrooms  bedrooms  beds  \
# 2609 -71.151437        1.0       1.0   3.0
# 2014 -71.071720        1.0       1.0   1.0
# 407  -71.098055        2.0       1.0   1.0
# 1188 -71.072263        1.0       2.0   1.0
# 1084 -71.077470        1.0       0.0   1.0
#
#                                               amenities  security_deposit  \
# 2609  internet,wireless internet,air conditioning,ki...               0.0
# 2014  tv,cable tv,internet,wireless internet,air con...             500.0
# 407   tv,cable tv,internet,wireless internet,air con...               0.0
# 1188  tv,cable tv,internet,wireless internet,air con...             250.0
# 1084  tv,cable tv,wireless internet,air conditioning...               0.0
#
#       cleaning_fee  minimum_nights  number_of_reviews  review_scores_rating  \
# 2609          30.0               1                 16                  89.0
# 2014         100.0               2                  9                  89.0
# 407           35.0               1                  0                  -1.0
# 1188          65.0               1                  6                 100.0
# 1084         225.0               7                  0                  -1.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 2609                     8.0                        9.0
# 2014                    10.0                        9.0
# 407                     -1.0                       -1.0
# 1188                    10.0                       10.0
# 1084                    -1.0                       -1.0
#
#       review_scores_checkin  review_scores_communication  \
# 2609                   10.0                         10.0
# 2014                    9.0                          9.0
# 407                    -1.0                         -1.0
# 1188                   10.0                         10.0
# 1084                   -1.0                         -1.0
#
#       review_scores_location  review_scores_value  instant_bookable  \
# 2609                     9.0                  9.0                 0
# 2014                    10.0                  9.0                 0
# 407                     -1.0                 -1.0                 0
# 1188                    10.0                 10.0                 0
# 1084                    -1.0                 -1.0                 0
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 1084                        0                   0                   0
#
#       property_type_Villa  property_type_Camper/RV  \
# 2609                    0                        0
# 2014                    0                        0
# 407                     0                        0
# 1188                    0                        0
# 1084                    0                        0
#
#       property_type_Entire Floor  room_type_Entire home/apt  \
# 2609                           0                          1
# 2014                           0                          1
# 407                            0                          0
# 1188                           0                          1
# 1084                           0                          1
#
#       room_type_Private room  room_type_Shared room  bed_type_Futon  \
# 2609                       0                      0               1
# 2014                       0                      0               0
# 407                        1                      0               0
# 1188                       0                      0               0
# 1084                       0                      0               0
#
#       bed_type_Real Bed  bed_type_Pull-out Sofa  bed_type_Airbed  \
# 2609                  0                       0                0
# 2014                  1                       0                0
# 407                   1                       0                0
# 1188                  1                       0                0
# 1084                  1                       0                0
#
#       bed_type_Couch  cancellation_policy_moderate  \
# 2609               0                             1
# 2014               0                             0
# 407                0                             0
# 1188               0                             0
# 1084               0                             0
#
#       cancellation_policy_strict  cancellation_policy_flexible  \
# 2609                           0                             0
# 2014                           1                             0
# 407                            1                             0
# 1188                           1                             0
# 1084                           1                             0
#
#       cancellation_policy_super_strict_30
# 2609                                    0
# 2014                                    0
# 407                                     0
# 1188                                    0
# 1084                                    0

# %%
X_train_tr.shape
# Out:
# (2509, 122)

# %%
X_test_tr = ohe_enc.transform(X_test)

X_test_tr.head()
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 3163               100.0                 100.0                  0
# 3133               100.0                  80.0                  1
# 937                100.0                 100.0                  0
# 196                100.0                 100.0                  1
# 2852               100.0                 100.0                  0
#
#       host_total_listings_count  host_identity_verified  city   latitude  \
# 3163                          1                       0     1  42.336777
# 3133                          1                       1     1  42.336180
# 937                           4                       1     1  42.345039
# 196                           2                       1     1  42.319620
# 2852                          0                       0     1  42.297679
#
#       longitude  bathrooms  bedrooms  beds  \
# 3163 -71.038163        1.0       1.0   1.0
# 3133 -71.027815        1.0       1.0   1.0
# 937  -71.062135        2.0       3.0   4.0
# 196  -71.104829        1.0       1.0   2.0
# 2852 -71.080782        1.0       1.0   1.0
#
#                                               amenities  security_deposit  \
# 3163  tv,wireless internet,air conditioning,kitchen,...             100.0
# 3133  tv,wireless internet,air conditioning,kitchen,...               0.0
# 937   tv,wireless internet,air conditioning,pool,kit...             500.0
# 196   tv,internet,wireless internet,air conditioning...             200.0
# 2852  wireless internet,family/kid friendly,smoke de...               0.0
#
#       cleaning_fee  minimum_nights  number_of_reviews  review_scores_rating  \
# 3163          30.0               1                 10                  96.0
# 3133          45.0               1                 26                  96.0
# 937          150.0               2                  1                  80.0
# 196           45.0               2                127                  97.0
# 2852          25.0               3                  0                  -1.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 3163                    10.0                       10.0
# 3133                    10.0                       10.0
# 937                     10.0                       10.0
# 196                     10.0                       10.0
# 2852                    -1.0                       -1.0
#
#       review_scores_checkin  review_scores_communication  \
# 3163                    9.0                          9.0
# 3133                   10.0                         10.0
# 937                     8.0                          8.0
# 196                    10.0                         10.0
# 2852                   -1.0                         -1.0
#
#       review_scores_location  review_scores_value  instant_bookable  \
# 3163                    10.0                 10.0                 0
# 3133                    10.0                  9.0                 0
# 937                      8.0                  8.0                 1
# 196                     10.0                 10.0                 1
# 2852                    -1.0                 -1.0                 0
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 2852                    0                        0
#
#       property_type_Entire Floor  room_type_Entire home/apt  \
# 3163                           0                          1
# 3133                           0                          0
# 937                            0                          1
# 196                            0                          1
# 2852                           0                          0
#
#       room_type_Private room  room_type_Shared room  bed_type_Futon  \
# 3163                       0                      0               0
# 3133                       1                      0               0
# 937                        0                      0               0
# 196                        0                      0               0
# 2852                       1                      0               0
#
#       bed_type_Real Bed  bed_type_Pull-out Sofa  bed_type_Airbed  \
# 3163                  1                       0                0
# 3133                  1                       0                0
# 937                   1                       0                0
# 196                   1                       0                0
# 2852                  1                       0                0
#
#       bed_type_Couch  cancellation_policy_moderate  \
# 3163               0                             1
# 3133               0                             1
# 937                0                             0
# 196                0                             0
# 2852               0                             1
#
#       cancellation_policy_strict  cancellation_policy_flexible  \
# 3163                           0                             0
# 3133                           0                             0
# 937                            1                             0
# 196                            1                             0
# 2852                           0                             0
#
#       cancellation_policy_super_strict_30
# 3163                                    0
# 3133                                    0
# 937                                     0
# 196                                     0
# 2852                                    0

# %%
X_test_tr.shape
# Out:
# (1076, 122)

# %%
X_test_tr.isna().sum().sort_values(ascending=False).head()
# Out:
# host_response_rate                     0
# neighbourhood_cleansed_Chinatown       0
# neighbourhood_cleansed_West End        0
# neighbourhood_cleansed_West Roxbury    0
# neighbourhood_cleansed_Downtown        0
# dtype: int64

# %% [markdown]
# All variables are transformed into numerical, encoded, and without null values!

# %%
X_train_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2509 entries, 2609 to 3174
# Columns: 122 entries, host_response_rate to cancellation_policy_super_strict_30
# dtypes: float64(17), int64(104), object(1)
# memory usage: 2.4+ MB

# %%
X_test_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1076 entries, 3163 to 2379
# Columns: 122 entries, host_response_rate to cancellation_policy_super_strict_30
# dtypes: float64(17), int64(104), object(1)
# memory usage: 1.0+ MB

# %%
X_train_tr.drop(['amenities'],axis=1,inplace=True)
X_test_tr.drop(['amenities'],axis=1,inplace=True)

# %% [markdown]
# # 4. Feature selection

# %% [markdown]
# ## 4.1. Constant features and quasi-constant features

# %%
constant_features = [
    feat for feat in X_train_tr.columns if X_train_tr[feat].std() == 0
]

# %%
constant_features
# Out:
# []

# %%
#drop the constant features
X_train_tr.drop(constant_features,axis=1,inplace=True)
X_test_tr.drop(constant_features,axis=1,inplace=True)

# %%
# remove quasi-constant features
sel = VarianceThreshold(
    threshold=0.01)  # 0.1 indicates 99% of observations approximately

sel.fit(X_train_tr)  # fit finds the features with low variance

sum(sel.get_support()) # how many not quasi-constant?
# Out:
# 104

# %%
X_train_tr.shape
# Out:
# (2509, 121)

# %%
features_not_keep = X_train_tr.columns[~sel.get_support()]

# %%
features_not_keep
# Out:
# Index(['latitude', 'longitude', 'free parking street', 'other pet(s)',
#        'paid parking premises', 'neighbourhood_cleansed_Hyde Park',
#        'neighbourhood_cleansed_Longwood Medical Area',
#        'neighbourhood_cleansed_Bay Village', 'neighbourhood_cleansed_Mattapan',
#        'neighbourhood_cleansed_Leather District', 'property_type_Other',
#        'property_type_Boat', 'property_type_Villa', 'property_type_Camper/RV',
#        'property_type_Entire Floor', 'bed_type_Pull-out Sofa',
#        'bed_type_Couch'],
#       dtype='object')

# %% [markdown]
# I will not remove the quasi-constant features for now

# %% [markdown]
# ## 4.2. Remove correlated features

# %%
# find and remove correlated features

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    
    corr_matrix = dataset.corr()
    
    for i in range(len(corr_matrix.columns)):
    
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_train_tr, 0.8)
print('correlated features: ', len(set(corr_features)) )
# Out:
# correlated features:  8

# %%
corr_features
# Out:
# {'review_scores_accuracy',
#  'review_scores_checkin',
#  'review_scores_cleanliness',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'room_type_Private room',
#  'washer'}

# %%
X_train_tr.shape
# Out:
# (2509, 92)

# %%
X_train_new = X_train_tr.drop(['security_deposit','cleaning_fee'],axis=1,inplace=True)
X_test_new = X_test_tr.drop(['security_deposit','cleaning_fee'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train_tr)

X_train_scaled = scaler.transform(X_train_tr)
X_test_scaled = scaler.transform(X_test_tr)

# %%
X_test_tr.shape
# Out:
# (1076, 119)

# %%
X_train_scaled
# Out:
# array([[ 0.37218797, -0.26965039, -0.36642548, ..., -0.89362537,
#         -0.61836005, -0.15109331],
#        [ 0.20928878, -0.85706332, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        [ 0.37218797,  0.70937115, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        ...,
#        [-0.1979592 , -1.39552516, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        [ 0.37218797,  0.66042007, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        [ 0.37218797, -0.22069932,  2.72906787, ..., -0.89362537,
#         -0.61836005, -0.15109331]])

# %%
X_test_scaled
# Out:
# array([[ 0.37218797,  0.70937115, -0.36642548, ..., -0.89362537,
#         -0.61836005, -0.15109331],
#        [ 0.37218797, -0.26965039,  2.72906787, ..., -0.89362537,
#         -0.61836005, -0.15109331],
#        [ 0.37218797,  0.70937115, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        ...,
#        [ 0.37218797,  0.36671361, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        [ 0.37218797,  0.31776253, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331],
#        [ 0.20928878, -1.49342732, -0.36642548, ...,  1.11903716,
#         -0.61836005, -0.15109331]])

# %%
X_test_tr.shape
# Out:
# (1076, 119)

# %%
X_train_tr.shape
# Out:
# (2509, 119)

# %% [markdown]
# # 5. Feature scaling
# Before the modelling part, and depending on the model itself. E.g. tree models do not require feature scaling

# %%
y_test.head()
# Out:
# 3163    103.33
# 3133     80.00
# 937      58.33
# 196      64.50
# 2852     18.33
# Name: price_per_person, dtype: float64

# %%
rf = RandomForestRegressor(n_estimators=200,max_depth=10, random_state=42)
rf.fit(X_train_tr, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=200, random_state=42)

# %%
pred = rf.predict(X_train_tr)

# %%
pred_test = rf.predict(X_test_tr)

# %%
#R 2 based on training set
r2_score(y_train,pred)
# Out:
# 0.6899959263206916

# %%
mean_squared_error(y_train,pred)
# Out:
# 391.23655938532255

# %%
pred_test
# Out:
# array([62.229591  , 64.25007103, 65.64730618, ..., 64.86461959,
#        44.72431308, 48.31740565])

# %%
#R 2 based on training set
r2_score(y_test,pred_test)
# Out:
# 0.061569995111233955

# %%
y_test
# Out:
# 3163    103.33
# 3133     80.00
# 937      58.33
# 196      64.50
# 2852     18.33
# 120      76.25
# 2284     63.00
# 3208     30.00
# 2823     21.67
# 498      33.33
# 1226     37.50
# 435      46.67
# 365      36.43
# 1940     32.50
# 276      50.00
# 2379     33.17
# Name: price_per_person, dtype: float64

# %%
X_test_tr.head(5)
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 3163               100.0                 100.0                  0
# 3133               100.0                  80.0                  1
# 937                100.0                 100.0                  0
# 196                100.0                 100.0                  1
# 2852               100.0                 100.0                  0
#
#       host_total_listings_count  host_identity_verified  city   latitude  \
# 3163                          1                       0     1  42.336777
# 3133                          1                       1     1  42.336180
# 937                           4                       1     1  42.345039
# 196                           2                       1     1  42.319620
# 2852                          0                       0     1  42.297679
#
#       longitude  bathrooms  bedrooms  beds  minimum_nights  number_of_reviews  \
# 3163 -71.038163        1.0       1.0   1.0               1                 10
# 3133 -71.027815        1.0       1.0   1.0               1                 26
# 937  -71.062135        2.0       3.0   4.0               2                  1
# 196  -71.104829        1.0       1.0   2.0               2                127
# 2852 -71.080782        1.0       1.0   1.0               3                  0
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 3163                  96.0                    10.0                       10.0
# 3133                  96.0                    10.0                       10.0
# 937                   80.0                    10.0                       10.0
# 196                   97.0                    10.0                       10.0
# 2852                  -1.0                    -1.0                       -1.0
#
#       review_scores_checkin  review_scores_communication  \
# 3163                    9.0                          9.0
# 3133                   10.0                         10.0
# 937                     8.0                          8.0
# 196                    10.0                         10.0
# 2852                   -1.0                         -1.0
#
#       review_scores_location  review_scores_value  instant_bookable  \
# 3163                    10.0                 10.0                 0
# 3133                    10.0                  9.0                 0
# 937                      8.0                  8.0                 1
# 196                     10.0                 10.0                 1
# 2852                    -1.0                 -1.0                 0
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# 3163                              0                                 0
# 3133                              0                                 0
# 937                               0                                 0
# 196                               0                                 0
# 2852                              0                                 0
#
#       reviews_per_month  days_operation  same_neigh  24-hour check-in  \
# 3163               0.55             617           1                 0
# 3133               1.54             559           1                 0
# 937                1.00            1230           1                 0
# 196                5.08             784           1                 1
# 2852              -1.00             993           0                 0
#
#       air conditioning  breakfast  buzzer/wireless intercom  cable tv  \
# 3163                 1          0                         0         1
# 3133                 1          0                         1         1
# 937                  1          0                         0         1
# 196                  1          0                         0         1
# 2852                 0          0                         0         0
#
#       carbon monoxide detector  cat(s)  dog(s)  doorman  dryer  \
# 3163                         0       0       0        0      0
# 3133                         1       0       0        0      1
# 937                          0       0       0        0      1
# 196                          1       0       0        0      1
# 2852                         1       0       0        0      0
#
#       elevator building  essentials  family/kid friendly  fire extinguisher  \
# 3163                  0           1                    0                  0
# 3133                  0           0                    0                  0
# 937                   1           1                    1                  0
# 196                   0           1                    1                  1
# 2852                  0           0                    1                  0
#
#       first aid kit  free parking premises  free parking street  gym  \
# 3163              0                      0                    0    0
# 3133              0                      0                    0    0
# 937               0                      0                    0    1
# 196               1                      1                    0    0
# 2852              1                      0                    0    0
#
#       hair dryer  hangers  heating  hot tub  indoor fireplace  internet  iron  \
# 3163           1        0        1        0                 0         1     1
# 937                                  0                                 0
# 196                                  0                                 0
# 2852                                 0                                 0
#
#       neighbourhood_cleansed_South Boston Waterfront  \
# 3163                                               0
# 3133                                               0
# 937                                                0
# 196                                                0
# 2852                                               0
#
#       neighbourhood_cleansed_Fenway  \
# 3163                              0
# 3133                              0
# 937                               0
# 196                               0
# 2852                              0
#
#       neighbourhood_cleansed_Longwood Medical Area  \
# 3163                                             0
# 3133                                             0
# 937                                              0
# 196                                              0
# 2852                                             0
#
#       neighbourhood_cleansed_Bay Village  neighbourhood_cleansed_Roslindale  \
# 3163                                   0                                  0
# 3133                                   0                                  0
# 937                                    0                                  0
# 196                                    0                                  0
# 2852                                   0                                  0
#
#       neighbourhood_cleansed_Mattapan  \
# 3163                                0
# 3133                                0
# 937                                 0
# 196                                 0
# 2852                                0
#
#       neighbourhood_cleansed_Leather District  property_type_Condominium  \
# 3163                                        0                          0
# 3133                                        0                          0
# 937                                         0                          0
# 196                                         0                          0
# 2852                                        0                          0
#
#       property_type_Apartment  property_type_House  \
# 3163                        1                    0
# 3133                        1                    0
# 937                         1                    0
# 196                         1                    0
# 2852                        0                    1
#
#       property_type_Bed & Breakfast  property_type_Other  \
# 3163                              0                    0
# 3133                              0                    0
# 937                               0                    0
# 196                               0                    0
# 2852                              0                    0
#
#       property_type_Townhouse  property_type_Loft  property_type_Boat  \
# 3163                        0                   0                   0
# 3133                        0                   0                   0
# 937                         0                   0                   0
# 196                         0                   0                   0
# 2852                        0                   0                   0
#
#       property_type_Villa  property_type_Camper/RV  \
# 3163                    0                        0
# 3133                    0                        0
# 937                     0                        0
# 196                     0                        0
# 2852                    0                        0
#
#       property_type_Entire Floor  room_type_Entire home/apt  \
# 3163                           0                          1
# 3133                           0                          0
# 937                            0                          1
# 196                            0                          1
# 2852                           0                          0
#
#       room_type_Private room  room_type_Shared room  bed_type_Futon  \
# 3163                       0                      0               0
# 3133                       1                      0               0
# 937                        0                      0               0
# 196                        0                      0               0
# 2852                       1                      0               0
#
#       bed_type_Real Bed  bed_type_Pull-out Sofa  bed_type_Airbed  \
# 3163                  1                       0                0
# 3133                  1                       0                0
# 937                   1                       0                0
# 196                   1                       0                0
# 2852                  1                       0                0
#
#       bed_type_Couch  cancellation_policy_moderate  \
# 3163               0                             1
# 3133               0                             1
# 937                0                             0
# 196                0                             0
# 2852               0                             1
#
#       cancellation_policy_strict  cancellation_policy_flexible  \
# 3163                           0                             0
# 3133                           0                             0
# 937                            1                             0
# 196                            1                             0
# 2852                           0                             0
#
#       cancellation_policy_super_strict_30
# 3163                                    0
# 3133                                    0
# 937                                     0
# 196                                     0
# 2852                                    0

# %%
listings.iloc[3163]
# Out:
# id                                                                            4928894
# host_location                                                                       1
# host_response_time                                                     within an hour
# host_response_rate                                                              100.0
# host_acceptance_rate                                                            100.0
# host_is_superhost                                                                   0
# host_neighbourhood                                                       South Boston
# host_total_listings_count                                                           1
# host_verifications                                      ['email', 'phone', 'reviews']
# host_identity_verified                                                              0
# neighbourhood_cleansed                                                   South Boston
# city                                                                           Boston
# smart_location                                                             Boston, MA
# latitude                                                                    42.336777
# longitude                                                                  -71.038163
# is_location_exact                                                                   1
# property_type                                                               Apartment
# room_type                                                             Entire home/apt
# bathrooms                                                                         1.0
# bedrooms                                                                          1.0
# beds                                                                              1.0
# bed_type                                                                     Real Bed
# amenities                           {TV,"Wireless Internet","Air Conditioning",Kit...
# security_deposit                                                                100.0
# cleaning_fee                                                                     30.0
# minimum_nights                                                                      1
# number_of_reviews                                                                  10
# review_scores_rating                                                             96.0
# review_scores_accuracy                                                           10.0
# review_scores_cleanliness                                                        10.0
# review_scores_checkin                                                             9.0
# review_scores_communication                                                       9.0
# review_scores_location                                                           10.0
# review_scores_value                                                              10.0
# instant_bookable                                                                    0
# cancellation_policy                                                          moderate
# require_guest_profile_picture                                                       0
# require_guest_phone_verification                                                    0
# calculated_host_listings_count                                                      1
# reviews_per_month                                                                0.55
# days_operation                                                                    617
# price_per_person                                                               103.33
# Name: 3163, dtype: object

# %%
pred_test
# Out:
# array([62.229591  , 64.25007103, 65.64730618, ..., 64.86461959,
#        44.72431308, 48.31740565])

# %%
rf.feature_importances_
# Out:
# array([5.48367955e-02, 2.09336023e-02, 2.72098666e-03, 3.01588592e-02,
#        6.80767229e-03, 8.16331391e-04, 1.55642995e-01, 1.50394224e-01,
#        1.97401761e-02, 4.50567176e-03, 7.98105417e-03, 8.48167813e-03,
#        1.21061293e-02, 8.30144487e-03, 5.55012946e-03, 4.06757069e-03,
#        2.04283259e-03, 1.68091500e-03, 3.37873467e-03, 4.92128673e-03,
#        4.92720615e-03, 1.71995746e-03, 5.03904726e-03, 2.17709056e-02,
#        4.63578369e-02, 5.73190443e-03, 5.01043945e-03, 7.96415446e-03,
#        2.95083120e-03, 3.67999587e-03, 1.40304696e-02, 5.38270277e-03,
#        1.89489096e-02, 1.22173477e-02, 1.03361010e-02, 5.63411302e-03,
#        3.06140907e-03, 1.46802155e-02, 1.00562463e-02, 3.45312399e-03,
#        3.38443443e-03, 3.73241722e-03, 3.05127832e-05, 7.93068791e-03,
#        2.98804796e-03, 2.37112273e-03, 5.42044893e-03, 1.18669029e-02,
#        2.81618435e-03, 8.21252553e-03, 1.74121717e-03, 8.24902676e-03,
#        7.52224901e-03, 2.95658871e-03, 1.85299506e-05, 5.46741202e-07,
#        1.09838129e-02, 3.89639344e-03, 2.97547307e-03, 1.44757669e-03,
#        2.12437110e-03, 1.49162440e-02, 5.45808783e-03, 1.16512938e-02,
#        3.68427768e-03, 1.78440010e-03, 2.50121703e-03, 1.93017121e-03,
#        5.81826023e-03, 9.70415573e-03, 5.55021603e-04, 5.47469142e-03,
#        1.39214266e-03, 3.62572202e-04, 8.11533088e-04, 2.33428016e-02,
#        2.65754045e-03, 2.10684096e-04, 2.51613500e-03, 5.27966383e-04,
#        3.92702870e-04, 1.99662981e-05, 2.11821633e-04, 4.64675148e-04,
#        2.00868701e-03, 7.24210553e-05, 1.41976762e-04, 1.23058545e-04,
#        1.45037701e-04, 8.96462033e-03, 1.22322313e-02, 8.01754128e-06,
#        6.87464002e-04, 5.34578174e-04, 6.13458603e-04, 3.98823249e-07,
#        4.70836484e-03, 3.28459344e-03, 1.87260096e-03, 2.72803502e-04,
#        6.18668945e-04, 3.81459053e-04, 3.30999270e-03, 5.87407448e-05,
#        6.36818321e-06, 4.39344849e-05, 1.44697853e-05, 6.56474031e-03,
#        5.82105522e-03, 5.83668240e-03, 9.25943856e-04, 2.82101442e-03,
#        8.26246578e-06, 1.24849258e-03, 1.91686295e-03, 3.99037172e-03,
#        4.74665158e-03, 1.01066633e-02, 2.08298735e-02])

# %%
feat_importances = pd.Series(rf.feature_importances_, index=X_train_tr.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.title("Top 15 important features")
plt.show()

# %%
rf1 = RandomForestRegressor(n_estimators=300, random_state=42)
rf1.fit(X_test_tr, y_test)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
pred = rf1.predict(X_test_tr)

# %%
#R 2 based on training set
r2_score(y_test,pred)
# Out:
# 0.8793489613044723

# %%
feat_importances = pd.Series(rf1.feature_importances_, index=X_test_tr.columns)
feat_importances.nlargest(25).plot(kind='barh')
plt.title("Top 15 important features")
plt.show()

# %%
X_test_tr['days_operation'].min()
# Out:
# 1

# %%
X_train_tr['days_operation'].min()
# Out:
# 1

# %%
X_train['property_type'].value_counts()/X_train.shape[0]
# Out:
# Apartment          0.734954
# House              0.156636
# Condominium        0.060980
# Bed & Breakfast    0.013153
# Townhouse          0.012356
# Loft               0.011160
# Other              0.003986
# Boat               0.003587
# Villa              0.001594
# Entire Floor       0.001196
# Camper/RV          0.000399
# Name: property_type, dtype: float64

# %%
X_test['property_type'].value_counts()/X_test.shape[0]
# Out:
# Apartment          0.716543
# House              0.157063
# Condominium        0.072491
# Townhouse          0.021375
# Loft               0.010223
# Bed & Breakfast    0.007435
# Other              0.006506
# Boat               0.002788
# Dorm               0.001859
# Villa              0.001859
# Guesthouse         0.000929
# Entire Floor       0.000929
# Name: property_type, dtype: float64

# %%
y_train.describe()
# Out:
# count    2509.000000
# mean       52.298489
# std        35.532239
# min         2.750000
# 25%        33.330000
# 50%        46.250000
# 75%        63.000000
# max       686.000000
# Name: price_per_person, dtype: float64

# %%
y_test.describe()
# Out:
# count    1076.000000
# mean       52.042314
# std        38.479849
# min         9.800000
# 25%        33.000000
# 50%        46.000000
# 75%        60.000000
# max       716.670000
# Name: price_per_person, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train_scaled)
r2_score(y_train,y_pred)
# Out:
# 0.19101533686407346

# %%
y_pred_test = lr.predict(X_test_scaled)
r2_score(y_test, y_pred_test)
# Out:
# -1.8945117748829765e+18

# %%
X_train_tr.describe().transpose()
# Out:
#                                                  count        mean  \
# host_response_rate                              2509.0   95.430450
# host_acceptance_rate                            2509.0   85.508569
# host_is_superhost                               2509.0    0.118374
# host_total_listings_count                       2509.0   58.889996
# host_identity_verified                          2509.0    0.729773
# city                                            2509.0    0.944201
# latitude                                        2509.0   42.340250
# longitude                                       2509.0  -71.084777
# bathrooms                                       2509.0    1.226983
# bedrooms                                        2509.0    1.256676
# beds                                            2509.0    1.604623
# minimum_nights                                  2509.0    3.126345
# number_of_reviews                               2509.0   18.989239
# review_scores_rating                            2509.0   71.050618
# review_scores_accuracy                          2509.0    7.040654
# review_scores_cleanliness                       2509.0    6.944201
# review_scores_checkin                           2509.0    7.223196
# review_scores_communication                     2509.0    7.226784
# review_scores_location                          2509.0    7.047031
# review_scores_value                             2509.0    6.858111
# instant_bookable                                2509.0    0.166600
# require_guest_profile_picture                   2509.0    0.017138
# require_guest_phone_verification                2509.0    0.063372
# reviews_per_month                               2509.0    1.359454
# days_operation                                  2509.0  897.855321
# same_neigh                                      2509.0    0.522120
# 24-hour check-in                                2509.0    0.354324
# air conditioning                                2509.0    0.793942
# breakfast                                       2509.0    0.088083
# buzzer/wireless intercom                        2509.0    0.243523
# cable tv                                        2509.0    0.755281
# carbon monoxide detector                        2509.0    0.684336
# cat(s)                                          2509.0    0.051415
# dog(s)                                          2509.0    0.066162
# doorman                                         2509.0    0.076923
# dryer                                           2509.0    0.698286
# elevator building                               2509.0    0.248705
# essentials                                      2509.0    0.834197
# family/kid friendly                             2509.0    0.530490
# fire extinguisher                               2509.0    0.437226
# first aid kit                                   2509.0    0.297330
# free parking premises                           2509.0    0.232363
# free parking street                             2509.0    0.001196
# gym                                             2509.0    0.134316
# hair dryer                                      2509.0    0.510961
# hangers                                         2509.0    0.560383
# heating                                         2509.0    0.941411
# hot tub                                         2509.0    0.049422
# indoor fireplace                                2509.0    0.117577
# internet                                        2509.0    0.962933
# iron                                            2509.0    0.520128
# kitchen                                         2509.0    0.913113
# laptop friendly workspace                       2509.0    0.521323
# lock bedroom door                               2509.0    0.131925
# other pet(s)                                    2509.0    0.003986
# paid parking premises                           2509.0    0.001594
# pets allowed                                    2509.0    0.135512
# pets live property                              2509.0    0.119171
# pool                                            2509.0    0.045038
# safety card                                     2509.0    0.131527
# shampoo                                         2509.0    0.673974
# smoke detector                                  2509.0    0.811080
# smoking allowed                                 2509.0    0.027900
# suitable events                                 2509.0    0.040255
# washer                                          2509.0    0.695496
# wheelchair accessible                           2509.0    0.044639
# host_response_time_within a few hours           2509.0    0.345556
# host_response_time_within a day                 2509.0    0.130729
# host_response_time_within an hour               2509.0    0.383021
# host_response_time_-1                           2509.0    0.126345
# host_response_time_a few days or more           2509.0    0.014348
# neighbourhood_cleansed_Brighton                 2509.0    0.051415
# neighbourhood_cleansed_Beacon Hill              2509.0    0.054205
# neighbourhood_cleansed_Mission Hill             2509.0    0.032682
# neighbourhood_cleansed_South End                2509.0    0.088880
# neighbourhood_cleansed_Roxbury                  2509.0    0.039458
# neighbourhood_cleansed_East Boston              2509.0    0.039857
# neighbourhood_cleansed_Charlestown              2509.0    0.029494
# neighbourhood_cleansed_Back Bay                 2509.0    0.088481
# neighbourhood_cleansed_Allston                  2509.0    0.074133
# neighbourhood_cleansed_Dorchester               2509.0    0.077322
# neighbourhood_cleansed_Hyde Park                2509.0    0.009167
# neighbourhood_cleansed_Jamaica Plain            2509.0    0.089677
# neighbourhood_cleansed_South Boston             2509.0    0.048625
# neighbourhood_cleansed_Downtown                 2509.0    0.051813
# neighbourhood_cleansed_West Roxbury             2509.0    0.013551
# neighbourhood_cleansed_West End                 2509.0    0.015145
# neighbourhood_cleansed_North End                2509.0    0.041052
# neighbourhood_cleansed_Chinatown                2509.0    0.018334
# neighbourhood_cleansed_South Boston Waterfront  2509.0    0.023515
# neighbourhood_cleansed_Fenway                   2509.0    0.082902
# neighbourhood_cleansed_Longwood Medical Area    2509.0    0.002790
# neighbourhood_cleansed_Bay Village              2509.0    0.005580
# neighbourhood_cleansed_Roslindale               2509.0    0.014747
# neighbourhood_cleansed_Mattapan                 2509.0    0.005978
# neighbourhood_cleansed_Leather District         2509.0    0.001196
# property_type_Condominium                       2509.0    0.060980
# property_type_Apartment                         2509.0    0.734954
# property_type_House                             2509.0    0.156636
# property_type_Bed & Breakfast                   2509.0    0.013153
# property_type_Other                             2509.0    0.003986
# property_type_Townhouse                         2509.0    0.012356
# property_type_Loft                              2509.0    0.011160
# property_type_Boat                              2509.0    0.003587
# property_type_Villa                             2509.0    0.001594
# property_type_Camper/RV                         2509.0    0.000399
# property_type_Entire Floor                      2509.0    0.001196
# room_type_Entire home/apt                       2509.0    0.589478
# room_type_Private room                          2509.0    0.388202
# room_type_Shared room                           2509.0    0.022320
# bed_type_Futon                                  2509.0    0.015544
# bed_type_Real Bed                               2509.0    0.960542
# bed_type_Pull-out Sofa                          2509.0    0.008768
# bed_type_Airbed                                 2509.0    0.011558
# bed_type_Couch                                  2509.0    0.003587
# cancellation_policy_moderate                    2509.0    0.257075
# cancellation_policy_strict                      2509.0    0.444002
# cancellation_policy_flexible                    2509.0    0.276604
# cancellation_policy_super_strict_30             2509.0    0.022320
#
#                                                        std        min  \
# host_response_rate                               12.279979   0.000000
# host_acceptance_rate                             20.432632   0.000000
# host_is_superhost                                 0.323115   0.000000
# host_total_listings_count                       170.648759   0.000000
# host_identity_verified                            0.444166   0.000000
# city                                              0.229579   0.000000
# latitude                                          0.024402  42.235942
# longitude                                         0.031646 -71.171789
# bathrooms                                         0.509277   0.000000
# bedrooms                                          0.751580   0.000000
# beds                                              1.024381   0.000000
# minimum_nights                                    7.454619   1.000000
# number_of_reviews                                35.007511   0.000000
# review_scores_rating                             39.751303  -1.000000
# review_scores_accuracy                            4.461686  -1.000000
# review_scores_cleanliness                         4.419680  -1.000000
# review_scores_checkin                             4.518746  -1.000000
# review_scores_communication                       4.513137  -1.000000
# review_scores_location                            4.451334  -1.000000
# review_scores_value                               4.368561  -1.000000
# instant_bookable                                  0.372693   0.000000
# require_guest_profile_picture                     0.129813   0.000000
# require_guest_phone_verification                  0.243679   0.000000
# reviews_per_month                                 2.270770  -1.000000
# days_operation                                  624.140339   1.000000
# same_neigh                                        0.499610   0.000000
# 24-hour check-in                                  0.478403   0.000000
# air conditioning                                  0.404553   0.000000
# breakfast                                         0.283472   0.000000
# buzzer/wireless intercom                          0.429294   0.000000
# cable tv                                          0.430006   0.000000
# carbon monoxide detector                          0.464872   0.000000
# cat(s)                                            0.220887   0.000000
# dog(s)                                            0.248614   0.000000
# doorman                                           0.266522   0.000000
# dryer                                             0.459093   0.000000
# elevator building                                 0.432348   0.000000
# essentials                                        0.371978   0.000000
# family/kid friendly                               0.499169   0.000000
# fire extinguisher                                 0.496143   0.000000
# first aid kit                                     0.457174   0.000000
# free parking premises                             0.422424   0.000000
# free parking street                               0.034565   0.000000
# gym                                               0.341060   0.000000
# hair dryer                                        0.499979   0.000000
# hangers                                           0.496439   0.000000
# heating                                           0.234901   0.000000
# hot tub                                           0.216791   0.000000
# indoor fireplace                                  0.322170   0.000000
# internet                                          0.188963   0.000000
# iron                                              0.499694   0.000000
# kitchen                                           0.281726   0.000000
# laptop friendly workspace                         0.499645   0.000000
# lock bedroom door                                 0.338477   0.000000
# other pet(s)                                      0.063019   0.000000
# paid parking premises                             0.039904   0.000000
# pets allowed                                      0.342338   0.000000
# pets live property                                0.324054   0.000000
# pool                                              0.207429   0.000000
# safety card                                       0.338043   0.000000
# shampoo                                           0.468850   0.000000
# smoke detector                                    0.391523   0.000000
# smoking allowed                                   0.164718   0.000000
# suitable events                                   0.196596   0.000000
# washer                                            0.460289   0.000000
# wheelchair accessible                             0.206552   0.000000
# host_response_time_within a few hours             0.475644   0.000000
# host_response_time_within a day                   0.337171   0.000000
# host_response_time_within an hour                 0.486220   0.000000
# host_response_time_-1                             0.332304   0.000000
# host_response_time_a few days or more             0.118946   0.000000
# neighbourhood_cleansed_Brighton                   0.220887   0.000000
# neighbourhood_cleansed_Beacon Hill                0.226467   0.000000
# neighbourhood_cleansed_Mission Hill               0.177839   0.000000
# neighbourhood_cleansed_South End                  0.284627   0.000000
# neighbourhood_cleansed_Roxbury                    0.194721   0.000000
# neighbourhood_cleansed_East Boston                0.195661   0.000000
# neighbourhood_cleansed_Charlestown                0.169220   0.000000
# neighbourhood_cleansed_Back Bay                   0.284050   0.000000
# neighbourhood_cleansed_Allston                    0.262040   0.000000
# neighbourhood_cleansed_Dorchester                 0.267154   0.000000
# neighbourhood_cleansed_Hyde Park                  0.095324   0.000000
# neighbourhood_cleansed_Jamaica Plain              0.285776   0.000000
# neighbourhood_cleansed_South Boston               0.215126   0.000000
# neighbourhood_cleansed_Downtown                   0.221694   0.000000
# neighbourhood_cleansed_West Roxbury               0.115641   0.000000
# neighbourhood_cleansed_West End                   0.122156   0.000000
# neighbourhood_cleansed_North End                  0.198451   0.000000
# neighbourhood_cleansed_Chinatown                  0.134183   0.000000
# neighbourhood_cleansed_South Boston Waterfront    0.151564   0.000000
# neighbourhood_cleansed_Fenway                     0.275788   0.000000
# neighbourhood_cleansed_Longwood Medical Area      0.052757   0.000000
# neighbourhood_cleansed_Bay Village                0.074505   0.000000
# neighbourhood_cleansed_Roslindale                 0.120562   0.000000
# neighbourhood_cleansed_Mattapan                   0.077105   0.000000
# neighbourhood_cleansed_Leather District           0.034565   0.000000
# property_type_Condominium                         0.239342   0.000000
# property_type_Apartment                           0.441446   0.000000
# property_type_House                               0.363530   0.000000
# property_type_Bed & Breakfast                     0.113951   0.000000
# property_type_Other                               0.063019   0.000000
# property_type_Townhouse                           0.110489   0.000000
# property_type_Loft                                0.105070   0.000000
# property_type_Boat                                0.059797   0.000000
# property_type_Villa                               0.039904   0.000000
# property_type_Camper/RV                           0.019964   0.000000
# property_type_Entire Floor                        0.034565   0.000000
# room_type_Entire home/apt                         0.492027   0.000000
# room_type_Private room                            0.487438   0.000000
# room_type_Shared room                             0.147750   0.000000
# bed_type_Futon                                    0.123728   0.000000
# bed_type_Real Bed                                 0.194721   0.000000
# bed_type_Pull-out Sofa                            0.093247   0.000000
# bed_type_Airbed                                   0.106908   0.000000
# bed_type_Couch                                    0.059797   0.000000
# cancellation_policy_moderate                      0.437108   0.000000
# cancellation_policy_strict                        0.496953   0.000000
# cancellation_policy_flexible                      0.447408   0.000000
# cancellation_policy_super_strict_30               0.147750   0.000000
#
#                                                        25%         50%  \
# host_response_rate                               98.000000  100.000000
# host_acceptance_rate                             78.000000   94.000000
# host_is_superhost                                 0.000000    0.000000
# host_total_listings_count                         1.000000    2.000000
# host_identity_verified                            0.000000    1.000000
# city                                              1.000000    1.000000
# latitude                                         42.330082   42.345393
# longitude                                       -71.104937  -71.078077
# bathrooms                                         1.000000    1.000000
# bedrooms                                          1.000000    1.000000
# beds                                              1.000000    1.000000
# minimum_nights                                    1.000000    2.000000
# number_of_reviews                                 1.000000    5.000000
# review_scores_rating                             70.000000   92.000000
# review_scores_accuracy                            7.000000    9.000000
# review_scores_cleanliness                         6.000000    9.000000
# review_scores_checkin                             8.000000   10.000000
# review_scores_communication                       8.000000   10.000000
# review_scores_location                            8.000000    9.000000
# review_scores_value                               7.000000    9.000000
# instant_bookable                                  0.000000    0.000000
# require_guest_profile_picture                     0.000000    0.000000
# require_guest_phone_verification                  0.000000    0.000000
# reviews_per_month                                 0.120000    0.780000
# days_operation                                  443.000000  765.000000
# same_neigh                                        0.000000    1.000000
# 24-hour check-in                                  0.000000    0.000000
# air conditioning                                  1.000000    1.000000
# breakfast                                         0.000000    0.000000
# buzzer/wireless intercom                          0.000000    0.000000
# cable tv                                          1.000000    1.000000
# carbon monoxide detector                          0.000000    1.000000
# cat(s)                                            0.000000    0.000000
# dog(s)                                            0.000000    0.000000
# doorman                                           0.000000    0.000000
# dryer                                             0.000000    1.000000
# elevator building                                 0.000000    0.000000
# essentials                                        1.000000    1.000000
# family/kid friendly                               0.000000    1.000000
# fire extinguisher                                 0.000000    0.000000
# first aid kit                                     0.000000    0.000000
# free parking premises                             0.000000    0.000000
# free parking street                               0.000000    0.000000
# gym                                               0.000000    0.000000
# hair dryer                                        0.000000    1.000000
# hangers                                           0.000000    1.000000
# heating                                           1.000000    1.000000
# hot tub                                           0.000000    0.000000
# indoor fireplace                                  0.000000    0.000000
# internet                                          1.000000    1.000000
# iron                                              0.000000    1.000000
# kitchen                                           1.000000    1.000000
# laptop friendly workspace                         0.000000    1.000000
# lock bedroom door                                 0.000000    0.000000
# other pet(s)                                      0.000000    0.000000
# paid parking premises                             0.000000    0.000000
# pets allowed                                      0.000000    0.000000
# pets live property                                0.000000    0.000000
# pool                                              0.000000    0.000000
# safety card                                       0.000000    0.000000
# shampoo                                           0.000000    1.000000
# smoke detector                                    1.000000    1.000000
# smoking allowed                                   0.000000    0.000000
# suitable events                                   0.000000    0.000000
# washer                                            0.000000    1.000000
# wheelchair accessible                             0.000000    0.000000
# host_response_time_within a few hours             0.000000    0.000000
# host_response_time_within a day                   0.000000    0.000000
# host_response_time_within an hour                 0.000000    0.000000
# host_response_time_-1                             0.000000    0.000000
# host_response_time_a few days or more             0.000000    0.000000
# neighbourhood_cleansed_Brighton                   0.000000    0.000000
# neighbourhood_cleansed_Beacon Hill                0.000000    0.000000
# neighbourhood_cleansed_Mission Hill               0.000000    0.000000
# neighbourhood_cleansed_South End                  0.000000    0.000000
# neighbourhood_cleansed_Roxbury                    0.000000    0.000000
# neighbourhood_cleansed_East Boston                0.000000    0.000000
# neighbourhood_cleansed_Charlestown                0.000000    0.000000
# neighbourhood_cleansed_Back Bay                   0.000000    0.000000
# neighbourhood_cleansed_Allston                    0.000000    0.000000
# neighbourhood_cleansed_Dorchester                 0.000000    0.000000
# neighbourhood_cleansed_Hyde Park                  0.000000    0.000000
# neighbourhood_cleansed_Jamaica Plain              0.000000    0.000000
# neighbourhood_cleansed_South Boston               0.000000    0.000000
# neighbourhood_cleansed_Downtown                   0.000000    0.000000
# neighbourhood_cleansed_West Roxbury               0.000000    0.000000
# neighbourhood_cleansed_West End                   0.000000    0.000000
# neighbourhood_cleansed_North End                  0.000000    0.000000
# neighbourhood_cleansed_Chinatown                  0.000000    0.000000
# neighbourhood_cleansed_South Boston Waterfront    0.000000    0.000000
# neighbourhood_cleansed_Fenway                     0.000000    0.000000
# neighbourhood_cleansed_Longwood Medical Area      0.000000    0.000000
# neighbourhood_cleansed_Bay Village                0.000000    0.000000
# neighbourhood_cleansed_Roslindale                 0.000000    0.000000
# neighbourhood_cleansed_Mattapan                   0.000000    0.000000
# neighbourhood_cleansed_Leather District           0.000000    0.000000
# property_type_Condominium                         0.000000    0.000000
# property_type_Apartment                           0.000000    1.000000
# property_type_House                               0.000000    0.000000
# property_type_Bed & Breakfast                     0.000000    0.000000
# property_type_Other                               0.000000    0.000000
# property_type_Townhouse                           0.000000    0.000000
# property_type_Loft                                0.000000    0.000000
# property_type_Boat                                0.000000    0.000000
# property_type_Villa                               0.000000    0.000000
# property_type_Camper/RV                           0.000000    0.000000
# property_type_Entire Floor                        0.000000    0.000000
# room_type_Entire home/apt                         0.000000    1.000000
# room_type_Private room                            0.000000    0.000000
# room_type_Shared room                             0.000000    0.000000
# bed_type_Futon                                    0.000000    0.000000
# bed_type_Real Bed                                 1.000000    1.000000
# bed_type_Pull-out Sofa                            0.000000    0.000000
# bed_type_Airbed                                   0.000000    0.000000
# bed_type_Couch                                    0.000000    0.000000
# cancellation_policy_moderate                      0.000000    0.000000
# cancellation_policy_strict                        0.000000    0.000000
# cancellation_policy_flexible                      0.000000    0.000000
# cancellation_policy_super_strict_30               0.000000    0.000000
#
#                                                         75%          max
# host_response_rate                               100.000000   100.000000
# host_acceptance_rate                             100.000000   100.000000
# host_is_superhost                                  0.000000     1.000000
# host_total_listings_count                          7.000000   749.000000
# host_identity_verified                             1.000000     1.000000
# city                                               1.000000     1.000000
# latitude                                          42.354910    42.389982
# longitude                                        -71.061995   -71.000100
# bathrooms                                          1.000000     6.000000
# bedrooms                                           2.000000     5.000000
# beds                                               2.000000    16.000000
# minimum_nights                                     3.000000   273.000000
# number_of_reviews                                 21.000000   312.000000
# review_scores_rating                              97.000000   100.000000
# review_scores_accuracy                            10.000000    10.000000
# review_scores_cleanliness                         10.000000    10.000000
# review_scores_checkin                             10.000000    10.000000
# review_scores_communication                       10.000000    10.000000
# review_scores_location                            10.000000    10.000000
# review_scores_value                               10.000000    10.000000
# instant_bookable                                   0.000000     1.000000
# require_guest_profile_picture                      0.000000     1.000000
# require_guest_phone_verification                   0.000000     1.000000
# reviews_per_month                                  2.160000    19.150000
# days_operation                                  1262.000000  2857.000000
# same_neigh                                         1.000000     1.000000
# 24-hour check-in                                   1.000000     1.000000
# air conditioning                                   1.000000     1.000000
# breakfast                                          0.000000     1.000000
# buzzer/wireless intercom                           0.000000     1.000000
# cable tv                                           1.000000     1.000000
# carbon monoxide detector                           1.000000     1.000000
# cat(s)                                             0.000000     1.000000
# dog(s)                                             0.000000     1.000000
# doorman                                            0.000000     1.000000
# dryer                                              1.000000     1.000000
# elevator building                                  0.000000     1.000000
# essentials                                         1.000000     1.000000
# family/kid friendly                                1.000000     1.000000
# fire extinguisher                                  1.000000     1.000000
# first aid kit                                      1.000000     1.000000
# free parking premises                              0.000000     1.000000
# free parking street                                0.000000     1.000000
# gym                                                0.000000     1.000000
# hair dryer                                         1.000000     1.000000
# hangers                                            1.000000     1.000000
# heating                                            1.000000     1.000000
# hot tub                                            0.000000     1.000000
# indoor fireplace                                   0.000000     1.000000
# internet                                           1.000000     1.000000
# iron                                               1.000000     1.000000
# kitchen                                            1.000000     1.000000
# laptop friendly workspace                          1.000000     1.000000
# lock bedroom door                                  0.000000     1.000000
# other pet(s)                                       0.000000     1.000000
# paid parking premises                              0.000000     1.000000
# pets allowed                                       0.000000     1.000000
# pets live property                                 0.000000     1.000000
# pool                                               0.000000     1.000000
# safety card                                        0.000000     1.000000
# shampoo                                            1.000000     1.000000
# smoke detector                                     1.000000     1.000000
# smoking allowed                                    0.000000     1.000000
# suitable events                                    0.000000     1.000000
# washer                                             1.000000     1.000000
# wheelchair accessible                              0.000000     1.000000
# host_response_time_within a few hours              1.000000     1.000000
# host_response_time_within a day                    0.000000     1.000000
# host_response_time_within an hour                  1.000000     1.000000
# host_response_time_-1                              0.000000     1.000000
# host_response_time_a few days or more              0.000000     1.000000
# neighbourhood_cleansed_Brighton                    0.000000     1.000000
# neighbourhood_cleansed_Beacon Hill                 0.000000     1.000000
# neighbourhood_cleansed_Mission Hill                0.000000     1.000000
# neighbourhood_cleansed_South End                   0.000000     1.000000
# neighbourhood_cleansed_Roxbury                     0.000000     1.000000
# neighbourhood_cleansed_East Boston                 0.000000     1.000000
# neighbourhood_cleansed_Charlestown                 0.000000     1.000000
# neighbourhood_cleansed_Back Bay                    0.000000     1.000000
# neighbourhood_cleansed_Allston                     0.000000     1.000000
# neighbourhood_cleansed_Dorchester                  0.000000     1.000000
# neighbourhood_cleansed_Hyde Park                   0.000000     1.000000
# neighbourhood_cleansed_Jamaica Plain               0.000000     1.000000
# neighbourhood_cleansed_South Boston                0.000000     1.000000
# neighbourhood_cleansed_Downtown                    0.000000     1.000000
# neighbourhood_cleansed_West Roxbury                0.000000     1.000000
# neighbourhood_cleansed_West End                    0.000000     1.000000
# neighbourhood_cleansed_North End                   0.000000     1.000000
# neighbourhood_cleansed_Chinatown                   0.000000     1.000000
# neighbourhood_cleansed_South Boston Waterfront     0.000000     1.000000
# neighbourhood_cleansed_Fenway                      0.000000     1.000000
# neighbourhood_cleansed_Longwood Medical Area       0.000000     1.000000
# neighbourhood_cleansed_Bay Village                 0.000000     1.000000
# neighbourhood_cleansed_Roslindale                  0.000000     1.000000
# neighbourhood_cleansed_Mattapan                    0.000000     1.000000
# neighbourhood_cleansed_Leather District            0.000000     1.000000
# property_type_Condominium                          0.000000     1.000000
# property_type_Apartment                            1.000000     1.000000
# property_type_House                                0.000000     1.000000
# property_type_Bed & Breakfast                      0.000000     1.000000
# property_type_Other                                0.000000     1.000000
# property_type_Townhouse                            0.000000     1.000000
# property_type_Loft                                 0.000000     1.000000
# property_type_Boat                                 0.000000     1.000000
# property_type_Villa                                0.000000     1.000000
# property_type_Camper/RV                            0.000000     1.000000
# property_type_Entire Floor                         0.000000     1.000000
# room_type_Entire home/apt                          1.000000     1.000000
# room_type_Private room                             1.000000     1.000000
# room_type_Shared room                              0.000000     1.000000
# bed_type_Futon                                     0.000000     1.000000
# bed_type_Real Bed                                  1.000000     1.000000
# bed_type_Pull-out Sofa                             0.000000     1.000000
# bed_type_Airbed                                    0.000000     1.000000
# bed_type_Couch                                     0.000000     1.000000
# cancellation_policy_moderate                       1.000000     1.000000
# cancellation_policy_strict                         1.000000     1.000000
# cancellation_policy_flexible                       1.000000     1.000000
# cancellation_policy_super_strict_30                0.000000     1.000000

# %%
#R 2 based on training set
r2_score(y_train,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xx/52xcnk8x57b6lb5ws1h4mj2c0000gn/T/ipykernel_4874/1763760891.py in <module>
#       1 #R 2 based on training set
# ----> 2 r2_score(y_train,pred)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     674     -3.0
#     675     """
# --> 676     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     677         y_true, y_pred, multioutput)
#     678     check_consistent_length(y_true, y_pred, sample_weight)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      86         the dtype argument passed to check_array.
#      87     """
# ---> 88     check_consistent_length(y_true, y_pred)
#      89     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      90     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     317     uniques = np.unique(lengths)
#     318     if len(uniques) > 1:
# --> 319         raise ValueError("Found input variables with inconsistent numbers of"
#     320                          " samples: %r" % [int(l) for l in lengths])
#     321
#
# ValueError: Found input variables with inconsistent numbers of samples: [2509, 1076]

# %%
#R 2 based on training set
r2_score(y_test,pred_test)
# Out:
# 0.09605997791276533
