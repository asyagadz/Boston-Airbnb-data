# %% [markdown]
# # Text analytics on Description field

# %% [markdown]
# In this notebook we are splitting separately the text preprocessing we did on the Description data.
# I performed text preprocessing in terms of cleaning, tokenization, lemmatization, and transformation of the text data into vectors, which are fed into a classification model.<br>
# I tried to understand whether there is a relationship between the description and the review score.
# After the text preprocessing, text data is transformed into numerical vectors, to be fed into a SVC. However, the metrics are quite bad, so I will not include the Description data into the features for predicting the prices. <br>
# This notebook is left here for reference purposes and as a trace.

# %%
#imports 
import pandas as pd
import numpy as np 

import regex as re
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick 
import matplotlib.dates as mdates
from matplotlib.ticker import PercentFormatter, FuncFormatter
# %matplotlib inline
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)
from cycler import cycler

import seaborn as sns
sns.set()

import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from textacy import preprocessing
import textacy

import spacy
nlp = spacy.load('en_core_web_sm')

from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from  sklearn.metrics  import accuracy_score
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# environment settings
pd.set_option('display.max_column',None)
pd.set_option('display.max_rows',None)

# %%
#read data
calendar = pd.read_csv('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/raw_data/calendar.csv')
listings =  pd.read_csv('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/raw_data/listings.csv')
reviews = pd.read_csv('/Users/asyagadzhalova/Documents/GitHub/Boston-Airbnb-data/src/data/raw_data/reviews.csv')

# %%
df = listings[['id','description','review_scores_value']].copy()

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (2764, 3)

# %%
pd.set_option('display.width', None)
df.head()
# Out:
#          id                                        description  \
# 1   3075044  Charming and quiet room in a second floor 1910...
# 2      6976  Come stay with a friendly, middle-aged guy in ...
# 3   1436513  Come experience the comforts of home away from...
# 4   7651065  My comfy, clean and relaxing home is one block...
# 5  12386020  Super comfy bedroom plus your own bathroom in ...
#
#    review_scores_value
# 1                  9.0
# 2                 10.0
# 3                 10.0
# 4                 10.0
# 5                 10.0

# %% [markdown]
# Steps performed:<br>
# 1.Data cleaning, consisting mainly of text normalization /no noise, data is relatively clean/ - textacy module
# 2. Linguisting processing - tokenization, POS tagging, lemmatization. For all of this I've used the spacy library and the pipeline from there for linguistic processing
# 3. I've used the build-in TFIDFVectorizer to transform the text data into td-idf vectors. I have fed the transformed features into Support Vector Classifier for performing multi-class classification with target variable - the Score of the listing. However, very poor classification metrics -> I would assume there is no relationship between the Description and the review score. <br>
#
# I cannot think of any other usage of the Description data. Of course, it could be pulled into the overall model for predicting the price.

# %% [markdown]
# ### Text cleaning

# %%
#use textacy for text normalization and preprocessing - removal of accents, hyphens, quotes etc.
def normalize(text):
    text = preprocessing.normalize.hyphenated_words(text)
    text = preprocessing.normalize.unicode(text)
    text = preprocessing.normalize.quotation_marks(text)
    return text

# %%
df['clean_descr'] = df['description'].map(normalize)

# %%
df.head()
# Out:
#          id                                        description  \
# 1   3075044  Charming and quiet room in a second floor 1910...
# 2      6976  Come stay with a friendly, middle-aged guy in ...
# 3   1436513  Come experience the comforts of home away from...
# 4   7651065  My comfy, clean and relaxing home is one block...
# 5  12386020  Super comfy bedroom plus your own bathroom in ...
#
#    review_scores_value                                        clean_descr
# 1                  9.0  Charming and quiet room in a second floor 1910...
# 2                 10.0  Come stay with a friendly, middle-aged guy in ...
# 3                 10.0  Come experience the comforts of home away from...
# 4                 10.0  My comfy, clean and relaxing home is one block...
# 5                 10.0  Super comfy bedroom plus your own bathroom in ...

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f917b00f160>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f917b00f040>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f917aff0a50>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f917b021800>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f91c8b6ae80>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f917aff0c10>)]

# %%
'''
Input: The doc input of spacy pipeline 
Output data: Lemmas 
'''
def extract_lemmas(doc, **kwargs):
    return [t.lemma_ for t in textacy.extract.words(doc, **kwargs)]


def extract_noun_phrases(doc, preceding_pos=['NOUN'], sep='_'):
    patterns = []
    for pos in preceding_pos:
        patterns.append(f"POS:{pos} POS:NOUN:+")
    spans = textacy.extract.matches.token_matches(doc, patterns=patterns)
    return [sep.join([t.lemma_ for t in s]) for s in spans]


def extract_entities(doc, include_types=None, sep='_'):

    ents = textacy.extract.entities(doc,
             include_types=include_types,
             exclude_types=None,
             drop_determiners=True,
             min_freq=1)

    return [sep.join([t.lemma_ for t in e])+'/'+e.label_ for e in ents]


def extract_nlp(doc):
    return {
    'lemmas'          : extract_lemmas(doc,
                                     exclude_pos = ['PART', 'PUNCT',
                                        'DET', 'PRON', 'SYM', 'SPACE'],
                                     filter_stops = False),
    'adjs_verbs'      : extract_lemmas(doc, include_pos = ['ADJ', 'VERB']),
    'nouns'           : extract_lemmas(doc, include_pos = ['NOUN', 'PROPN']),
    'noun_phrases'    : extract_noun_phrases(doc, ['NOUN']),
    'adj_noun_phrases': extract_noun_phrases(doc, ['ADJ']),
    'entities'        : extract_entities(doc, ['PERSON', 'ORG', 'GPE', 'LOC'])
    }

# %%
for col, values in extract_nlp(doc).items():
    print(f"{col}: {values}")
# Out:
# lemmas: ['place', 'be', 'close', 'to', 'home', 'be', 'warm', 'and', 'friendly', 'environment', 'design', 'connect', 'people', 'from', 'all', 'over', 'world', 'room', 'be', 'private', 'in', '4', 'bedroom', 'house', 'other', '2', 'bedroom', 'be', 'also', 'for', 'airbnb', 'traveler', 'just', 'like', 'check', 'in', 'time', '11', 'am', '4', 'pm', '7', 'pm', 'or', 'later', 'if', 'need', 'checkout', '10', 'am', 'Location:67', 'Broadway', 'somerville', 'Ma', '02145', 'Harvard', '3.1', 'mile', 'MIT', '3', 'mile', 'train', 'metro', '1.3', 'mile', 'Sullivan', 'square', 'Bus', 'Stop', 'Highland', 'street', 'at', 'corner', 'ensure', 'smooth', 'check', 'in', '1', 'must', 'have', 'cell', 'phone', 'call', 'or', 'text', 'phone', 'number', 'HIDDEN', 'or', 'on', 'app', '30', 'minute', 'prior', 'to', 'arrival', 'and', 'when', 'arrive', 'because', 'be', 'doorbell', 'in', 'big', 'apartment', 'complex', 'if', 'do', 'have', 'US', 'phone', 'will', 'gladly', 'meet', 'at', 'Dunkin', 'donut', 'next', 'door', 'can', 'connect', 'to', 'there', 'wifi', 'and', 'send', 'message', 'on', 'airbnb', '2', 'check', 'in', 'time', 'be', '11', 'am', '4', 'pm', '7', 'pm', '10', 'pm', 'early', 'can', 'check', 'in', 'be', '11:00am', 'because', 'checkout', 'for', 'other', 'guest', 'be', 'until', '10', 'am', '3', 'also', 'offer', 'airpo']
# adjs_verbs: ['close', 'warm', 'friendly', 'design', 'connect', 'private', 'airbnb', 'need', 'ensure', 'smooth', 'arrive', 'big', 'meet', 'connect', 'send', 'early', 'check', 'offer']
# nouns: ['place', 'home', 'environment', 'people', 'world', 'room', 'bedroom', 'house', 'bedroom', 'traveler', 'check', 'time', 'pm', 'pm', 'checkout', 'Location:67', 'Broadway', 'somerville', 'Ma', 'Harvard', 'mile', 'MIT', 'mile', 'train', 'metro', 'mile', 'Sullivan', 'square', 'Bus', 'Stop', 'Highland', 'street', 'corner', 'check', 'cell', 'phone', 'text', 'phone', 'number', 'HIDDEN', 'app', 'minute', 'arrival', 'doorbell', 'apartment', 'complex', 'phone', 'Dunkin', 'donut', 'door', 'wifi', 'message', 'airbnb', 'check', 'time', 'pm', 'pm', 'pm', 'checkout', 'guest', 'airpo']
# noun_phrases: ['bedroom_house', 'mile_train', 'cell_phone', 'phone_number', 'phone_number_HIDDEN', 'number_HIDDEN', 'apartment_complex']
# adj_noun_phrases: ['friendly_environment', 'airbnb_traveler', 'smooth_check', 'big_apartment', 'big_apartment_complex', 'next_door', 'other_guest']
# entities: ['Ma_02145_ /PERSON', 'Harvard/ORG', 'MIT/ORG', 'Sullivan_square/PERSON', 'US/GPE']

# %%
nlp_columns = list(extract_nlp(nlp.make_doc('')).keys())
print(nlp_columns)
# Out:
# ['lemmas', 'adjs_verbs', 'nouns', 'noun_phrases', 'adj_noun_phrases', 'entities']

# %%
for col in nlp_columns:
    df[col] = None

# %%
if spacy.prefer_gpu():
    print("Working on GPU.")
else:
    print("No GPU found, working on CPU.")
# Out:
# No GPU found, working on CPU.

# %% [markdown]
# ### Linguistic processing

# %%
nlp = spacy.load('en_core_web_sm')

# %%
batch_size = 50

for i in range(0, len(df), batch_size):
    docs = nlp.pipe(df['clean_descr'][i:i+batch_size])

    for j, doc in enumerate(docs):
        for col, values in extract_nlp(doc).items():
            df[col].iloc[i+j] = values
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.head()
# Out:
#          id                                        description  \
# 1   3075044  Charming and quiet room in a second floor 1910...
# 2      6976  Come stay with a friendly, middle-aged guy in ...
# 3   1436513  Come experience the comforts of home away from...
# 4   7651065  My comfy, clean and relaxing home is one block...
# 5  12386020  Super comfy bedroom plus your own bathroom in ...
#
#    review_scores_value                                        clean_descr  \
# 1                  9.0  Charming and quiet room in a second floor 1910...
# 2                 10.0  Come stay with a friendly, middle-aged guy in ...
# 3                 10.0  Come experience the comforts of home away from...
# 4                 10.0  My comfy, clean and relaxing home is one block...
# 5                 10.0  Super comfy bedroom plus your own bathroom in ...
#
#                                               lemmas  \
# 1  [charming, and, quiet, room, in, second, floor...
# 2  [come, stay, with, friendly, middle, aged, guy...
# 3  [come, experience, comfort, of, home, away, fr...
# 4  [comfy, clean, and, relax, home, be, one, bloc...
# 5  [super, comfy, bedroom, plus, own, bathroom, i...
#
#                                           adjs_verbs  \
# 1  [charming, quiet, second, quiet, shared, use, ...
# 2  [come, stay, friendly, middle, aged, safe, qui...
# 3  [experience, fabulous, available, sleep, large...
# 4  [comfy, clean, relax, quiet, residential, priv...
# 5  [super, comfy, big, sunny, outer, interested, ...
#
#                                                nouns  \
# 1  [room, floor, condo, building, room, size, bed...
# 2  [guy, Roslindale, neighborhood, Boston, room, ...
# 3  [comfort, home, home, bedroom, suite, Roslinda...
# 4  [home, block, bus, line, street, room, bed, ba...
# 5  [bedroom, bathroom, condo, Roslindale, neighbo...
#
#                                         noun_phrases  \
# 1  [condo_building, size_bed, darkening_curtain, ...
# 2  [cable_tv, folk_art, family_house, cable_tv, a...
# 3  [bedroom_suite, washer_dryer, home_gym, street...
# 4  [bus_line, half_bath, bus_line, half_bath, kit...
# 5  [minute_ride, driveway_parking, family_home, g...
#
#                                     adj_noun_phrases  \
# 1  [quiet_room, second_floor, full_size, full_siz...
# 2  [aged_guy, furnished_room, mexican_folk, mexic...
# 3  [fabulous_bedroom, fabulous_bedroom_suite, lar...
# 4  [residential_street, private_room, single_bed,...
# 5  [comfy_bedroom, own_bathroom, sunny_condo, out...
#
#                                             entities
# 1  [Boston/GPE, Roslindale/GPE, Boston/GPE, Arnol...
# 2                       [Roslindale/GPE, Boston/GPE]
# 3  [Roslindale/GPE, Boston/GPE, Boston/GPE, Bosto...
# 4  [AC_Clean/ORG, Air_Conditioned/ORG, Boston/GPE...
# 5  [Roslindale/GPE, Boston/GPE, Boston/GPE, Bosto...

# %%
df[nlp_columns] = df[nlp_columns].applymap(lambda items: ' '.join(items))

# %%
df.head()
# Out:
#          id                                        description  \
# 1   3075044  Charming and quiet room in a second floor 1910...
# 2      6976  Come stay with a friendly, middle-aged guy in ...
# 3   1436513  Come experience the comforts of home away from...
# 4   7651065  My comfy, clean and relaxing home is one block...
# 5  12386020  Super comfy bedroom plus your own bathroom in ...
#
#    review_scores_value                                        clean_descr  \
# 1                  9.0  Charming and quiet room in a second floor 1910...
# 2                 10.0  Come stay with a friendly, middle-aged guy in ...
# 3                 10.0  Come experience the comforts of home away from...
# 4                 10.0  My comfy, clean and relaxing home is one block...
# 5                 10.0  Super comfy bedroom plus your own bathroom in ...
#
#                                               lemmas  \
# 1  charming and quiet room in second floor 1910 c...
# 2  come stay with friendly middle aged guy in saf...
# 3  come experience comfort of home away from home...
# 4  comfy clean and relax home be one block away f...
# 5  super comfy bedroom plus own bathroom in big s...
#
#                                           adjs_verbs  \
# 1  charming quiet second quiet shared use pet fri...
# 2  come stay friendly middle aged safe quiet clea...
# 3  experience fabulous available sleep large size...
# 4  comfy clean relax quiet residential private in...
# 5  super comfy big sunny outer interested public ...
#
#                                                nouns  \
# 1  room floor condo building room size bed darken...
# 2  guy Roslindale neighborhood Boston room cable ...
# 3  comfort home home bedroom suite Roslindale nei...
# 4  home block bus line street room bed bath half ...
# 5  bedroom bathroom condo Roslindale neighborhood...
#
#                                         noun_phrases  \
# 1  condo_building size_bed darkening_curtain c_un...
# 2  cable_tv folk_art family_house cable_tv air_co...
# 3  bedroom_suite washer_dryer home_gym street_par...
# 4  bus_line half_bath bus_line half_bath kitchen_...
# 5  minute_ride driveway_parking family_home guest...
#
#                                     adj_noun_phrases  \
# 1  quiet_room second_floor full_size full_size_be...
# 2  aged_guy furnished_room mexican_folk mexican_f...
# 3  fabulous_bedroom fabulous_bedroom_suite large_...
# 4  residential_street private_room single_bed ful...
# 5  comfy_bedroom own_bathroom sunny_condo outer_n...
#
#                                             entities
# 1  Boston/GPE Roslindale/GPE Boston/GPE Arnold_Ar...
# 2                          Roslindale/GPE Boston/GPE
# 3  Roslindale/GPE Boston/GPE Boston/GPE Boston/GP...
# 4  AC_Clean/ORG Air_Conditioned/ORG Boston/GPE Ap...
# 5    Roslindale/GPE Boston/GPE Boston/GPE Boston/GPE

# %% [markdown]
# ### Transforming processed text into feature vectors
# To perform the transformation - always first do the split by train and test, to learn the vectors only from the training set and avoid data leakage on the test set

# %%
X_train, X_test, y_train, y_test = train_test_split(df['noun_phrases'], df['review_scores_value'], test_size=0.33,random_state = 42)

# %%
tfidf = TfidfVectorizer(min_df=2)
train_vectors = tfidf.fit_transform(X_train)
test_vectors = tfidf.transform(X_test)

# %%
test_vectors
# Out:
# <913x1445 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4595 stored elements in Compressed Sparse Row format>

# %%
train_vectors
# Out:
# <1851x1445 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10712 stored elements in Compressed Sparse Row format>

# %%
model = LinearSVC()
model.fit(train_vectors, y_train)
y_pred = model.predict(test_vectors)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.4403066812705367

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          4.0       0.00      0.00      0.00         3
#          5.0       0.00      0.00      0.00         1
#          6.0       0.00      0.00      0.00        16
#          7.0       0.00      0.00      0.00        14
#          8.0       0.17      0.09      0.12       110
#          9.0       0.45      0.47      0.46       362
#         10.0       0.48      0.55      0.51       407
#
#     accuracy                           0.44       913
#    macro avg       0.16      0.16      0.16       913
# weighted avg       0.41      0.44      0.42       913
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
tfidf.get_feature_names()
# Out:
# ['10_min',
#  '15min_walk',
#  '1_bath',
#  '24',
#  '24_hour',
#  '24_hour_concierge',
#  '24_hour_concierge_service',
#  '24_hour_concierge_service_',
#  '32in_led',
#  '32in_led_tv',
#  '5min_walk',
#  '7_concierge',
#  '7min_walk',
#  '_access',
#  '_bedroom',
#  '_bike',
#  '_bike_share',
#  '_bike_share_station',
#  '_ceiling',
#  '_discount',
#  '_foot',
#  '_fridge',
#  '_mail',
#  '_op',
#  '_refrigerator',
#  '_rise',
#  '_smoker',
#  '_stop',
#  '_student',
#  '_suite',
#  '_suite_bathroom',
#  '_top',
#  '_tub',
#  'a_burger',
#  'a_dunkin',
#  'access_code',
#  'access_parking',
#  'acre_property',
#  'aero_bed',
#  'aft_cabin',
#  'aft_deck',
#  'afternoon_sun',
#  'air_bed',
#  'air_bnb',
#  'air_condition',
#  'air_conditioner',
#  'air_conditioning',
#  'air_conditioning_property',
#  'air_mattress',
#  'airbnb_smartphone',
#  'airbnb_smartphone_app',
#  'airport_shuttle',
#  'airport_shuttle_bus',
#  'airport_station',
#  'airport_terminal',
#  'airport_traveler',
#  'alarm_clock',
#  'alarm_clock_radio',
#  'alarm_rental',
#  'amenity_package',
#  'amenity_resident',
#  'answer_question',
#  'apartment_building',
#  'apartment_community',
#  'apartment_complex',
#  'apartment_condo',
#  'apartment_door',
#  'apartment_feature',
#  'apartment_home',
#  'apartment_rental',
#  'apartment_residence',
#  'apartment_unit',
#  'apartment_w',
#  'area_',
#  'area_architecture',
#  'area_attraction',
#  'area_college',
#  'area_hospital',
#  'area_step',
#  'area_w',
#  'art_fitness',
#  'art_fitness_center',
#  'art_gallery',
#  'art_shower',
#  'art_shower_system',
#  'art_strength',
#  'art_strength_training',
#  'art_student',
#  'art_studio',
#  'awesome_nightspot',
#  'b_line',
#  'b_train',
#  'back_deck',
#  'back_garden',
#  'back_yard',
#  'backyard_porch',
#  'ball_court',
#  'bamboo_floor',
#  'bamboo_flooring',
#  'bar_area',
#  'bar_seating',
#  'baseball_field',
#  'basement_apartment',
#  'basement_playroom',
#  'basement_studio',
#  'basement_studio_apartment',
#  'basketball_court',
#  'basketball_hoop',
#  'bath_apartment',
#  'bath_brand',
#  'bath_condo',
#  'bath_room',
#  'bath_suite',
#  'bath_towel',
#  'bath_unit',
#  'bath_w',
#  'bathroom_accessory',
#  'bathroom_apartment',
#  'bathroom_caddy',
#  'bathroom_door',
#  'bay_window',
#  'beach_park',
#  'bed',
#  'bed_apartment',
#  'bed_condo',
#  'bed_frame',
#  'bed_linen',
#  'bed_room',
#  'bed_sheet',
#  'bed_unit',
#  'bedroom',
#  'bedroom_',
#  'bedroom_apartment',
#  'bedroom_area',
#  'bedroom_condo',
#  'bedroom_condominium',
#  'bedroom_door',
#  'bedroom_home',
#  'bedroom_house',
#  'bedroom_level',
#  'bedroom_loft',
#  'bedroom_penthouse',
#  'bedroom_residence',
#  'bedroom_space',
#  'bedroom_suite',
#  'bedroom_unit',
#  'bedroom_w',
#  'bicycle',
#  'bike_path',
#  'bike_rental',
#  'bike_ride',
#  'bike_room',
#  'bike_share',
#  'bike_share_station',
#  'bike_sharing',
#  'bike_storage',
#  'bike_trail',
#  'biking_trail',
#  'billiard_room',
#  'bistro_table',
#  'block_street',
#  'blow_dryer',
#  'board_game',
#  'bocce',
#  'bocce_ball',
#  'bocce_ball_court',
#  'body_spray',
#  'body_wash',
#  'book_shelf',
#  'book_store',
#  'booking_request',
#  'boston_harbor',
#  'bottle_opener',
#  'boutique_shop',
#  'boutique_shopping',
#  'box_code',
#  'boxing_area',
#  'br_apartment',
#  'breakfast_bar',
#  'breakfast_item',
#  'breakfast_nook',
#  'breakfast_offering',
#  'breakfast_table',
#  'breakfast_west',
#  'breathtaking_view',
#  'brick_building',
#  'brick_patio',
#  'brick_row',
#  'brick_row_house',
#  'brick_rowhouse',
#  'brick_sidewalk',
#  'brick_street',
#  'brick_townhouse',
#  'brick_wall',
#  'brownstone_apartment',
#  'brownstone_building',
#  'brownstone_home',
#  'brownstone_step',
#  'budget_traveler',
#  'building_amenity',
#  'building_feature',
#  'building_restoration',
#  'building_step',
#  'building_washer',
#  'bunk_bed',
#  'burner_gas',
#  'bus_',
#  'bus_access',
#  'bus_connection',
#  'bus_line',
#  'bus_ride',
#  'bus_route',
#  'bus_station',
#  'bus_stop',
#  'bus_transportation',
#  'business_center',
#  'business_district',
#  'business_lounge',
#  'business_traveler',
#  'business_trip',
#  'buzzing_seaport',
#  'c_unit',
#  'cab_ride',
#  'cable_access',
#  'cable_package',
#  'cable_service',
#  'cable_television',
#  'cable_tv',
#  'capacity_washer',
#  'car_rental',
#  'car_ride',
#  'car_share',
#  'cardio_club',
#  'cardio_equipment',
#  'cardio_theater',
#  'case_basis',
#  'cast_fountain',
#  'cast_iron',
#  'cast_iron_tub',
#  'catering_kitchen',
#  'ceiling_fan',
#  'ceiling_view',
#  'ceiling_window',
#  'cell_phone',
#  'center_cat',
#  'centric_community',
#  'century_amenity',
#  'century_architecture',
#  'century_brick',
#  'century_façade',
#  'century_feature',
#  'century_row',
#  'century_row_house',
#  'century_style',
#  'change_sheet',
#  'charge_cash',
#  'checkin_process',
#  'cheese_shop',
#  'chef_kitchen',
#  'city_amenity',
#  'city_attraction',
#  'city_biking',
#  'city_bus',
#  'city_center',
#  'city_event',
#  'city_experience',
#  'city_feeling',
#  'city_life',
#  'city_light',
#  'city_living',
#  'city_neighborhood',
#  'city_noise',
#  'city_park',
#  'city_skyline',
#  'city_view',
#  'class_accommodation',
#  'class_eatery',
#  'claw_foot',
#  'claw_foot_tub',
#  'claw_tub',
#  'clawfoot_tub',
#  'cleaning_fee',
#  'cleaning_pickup',
#  'cleaning_product',
#  'cleaning_service',
#  'cleaning_supply',
#  'clock_radio',
#  'closet_space',
#  'clothing_rack',
#  'club_chair',
#  'club_house',
#  'club_room',
#  'club_suite',
#  'cobblestone_street',
#  'cobblestone_walk',
#  'coffee_bar',
#  'coffee_house',
#  'coffee_lounge',
#  'coffee_machine',
#  'coffee_maker',
#  'coffee_pot',
#  'coffee_shop',
#  'coffee_table',
#  'coin_laundry',
#  'coin_op',
#  'college_campus',
#  'college_graduate',
#  'college_student',
#  'college_visit',
#  'combination_kitchen',
#  'community_garden',
#  'community_roof',
#  'community_roof_deck',
#  'commuter_line',
#  'commuter_rail',
#  'commuter_rail_station',
#  'commuter_rail_stop',
#  'computer_desk',
#  'computer_lounge',
#  'computer_lounge_area',
#  'concept_kitchen',
#  'concept_living',
#  'concept_living_area',
#  'concept_living_room',
#  'concept_living_space',
#  'concierge_building',
#  'concierge_desk',
#  'concierge_service',
#  'concierge_service_',
#  'conditioning_property',
#  'condo_building',
#  'conference_area',
#  'conference_room',
#  'connectivity_need',
#  'conservation_land',
#  'considerate_roommate',
#  'content_hidden',
#  'convenience_store',
#  'convention_center',
#  'cook_top',
#  'cooking_facility',
#  'cooking_need',
#  'cooking_oil',
#  'cooking_supply',
#  'cooking_tool',
#  'cooking_utensil',
#  'cookout_facility',
#  'corner_store',
#  'corner_unit',
#  'cost_accommodation',
#  'cotton_bed',
#  'cotton_bed_sheet',
#  'cotton_linen',
#  'cotton_sheet',
#  'count_sheet',
#  'counter_',
#  'counter_space',
#  'counter_top',
#  'countertop_dishwasher',
#  'couple_block',
#  'couple_minute',
#  'court_',
#  'courtyard_w',
#  'cream_cheese',
#  'cross_country',
#  'cross_street',
#  'crossing_area',
#  'crown_jewel',
#  'crown_molding',
#  'crown_moulding',
#  'cuppa_tea',
#  'custom_fitting',
#  'custom_kitchen',
#  'custom_linen',
#  'custom_platform',
#  'custom_platform_queen',
#  'custom_platform_queen_bed',
#  'customer_service',
#  'customer_service_repre',
#  'cutter_hotel',
#  'cutter_hotel_room',
#  'd_line',
#  'date_night',
#  'day_amenity',
#  'day_bed',
#  'day_min',
#  'day_trip',
#  'deck_access',
#  'deck_saltwater',
#  'deck_saltwater_pool',
#  'deck_space',
#  'deck_terrace',
#  'decker_family',
#  'decker_family_home',
#  'degree_view',
#  'deluxe_queen',
#  'deluxe_queen_bed',
#  'deluxe_queen_size',
#  'deluxe_queen_size_bed',
#  'den_',
#  'designer_furnishing',
#  'designer_kitchen',
#  'desk_area',
#  'desk_gaming',
#  'desk_gaming_lounge',
#  'desk_space',
#  'desktop_computer',
#  'dimmer_switch',
#  'dining_area',
#  'dining_nook',
#  'dining_option',
#  'dining_place',
#  'dining_restaurant',
#  'dining_room',
#  'dining_room_area',
#  'dining_room_seat',
#  'dining_room_table',
#  'dining_space',
#  'dining_table',
#  'dinning_restaurant',
#  'dinning_room',
#  'dishwasher_detergent',
#  'dog_park',
#  'door_code',
#  'door_man',
#  'door_subway',
#  'door_subway_service',
#  'downtown_access',
#  'downtown_apartment',
#  'downtown_area',
#  'downtown_crossing',
#  'downtown_crossing_area',
#  'downtown_culture',
#  'downtown_district',
#  'downtown_location',
#  'downtown_skyline',
#  'drawer_dresser',
#  'drawer_space',
#  'dresser_space',
#  'driveway_parking',
#  'driveway_parking_spot',
#  'drug_store',
#  'dryer_machine',
#  'dryer_sheet',
#  'duplex_apartment',
#  'duplex_home',
#  'dvd_player',
#  'e_',
#  'e_line',
#  'ear_plug',
#  'efficiency_studio',
#  'efficiency_washer',
#  'elevator_access',
#  'elevator_building',
#  'emergency_maintenance',
#  'emergency_maintenance_service',
#  'enclave_border',
#  'end_apartment',
#  'end_appliance',
#  'end_boutique',
#  'end_condo',
#  'end_cooking',
#  'end_cooking_tool',
#  'end_finish',
#  'end_furnishing',
#  'end_kitchen',
#  'end_location',
#  'end_neighborhood',
#  'end_restaurant',
#  'end_shopping',
#  'end_street',
#  'end_studio',
#  'end_table',
#  'enjoy_view',
#  'entertainment_center',
#  'entertainment_complex',
#  'entertainment_room',
#  'entertainment_system',
#  'entertainment_venue',
#  'entry_code',
#  'entry_foyer',
#  'entry_level',
#  'entry_way',
#  'era_bungalow',
#  'era_home',
#  'espresso_machine',
#  'espresso_maker',
#  'event_space',
#  'exercise_class',
#  'experience_team',
#  'family_friend',
#  'family_home',
#  'family_house',
#  'family_member',
#  'family_neighborhood',
#  'family_room',
#  'farm_house',
#  'farmer_market',
#  'feature_resident',
#  'feel_condominium',
#  'field_corner',
#  'field_stone',
#  'field_stone_fireplace',
#  'finger_tip',
#  'finish_line',
#  'fir_wood',
#  'fir_wood_floor',
#  'fire_pit',
#  'fire_place',
#  'fish_pond',
#  'fitness_center',
#  'fitness_trail',
#  'flatscreen_tv',
#  'floor_apartment',
#  'floor_bathroom',
#  'floor_bedroom',
#  'floor_brownstone',
#  'floor_building',
#  'floor_condo',
#  'floor_corner',
#  'floor_deck',
#  'floor_den',
#  'floor_den_',
#  'floor_hi',
#  'floor_hi_',
#  'floor_living',
#  'floor_living_area',
#  'floor_lounge',
#  'floor_master',
#  'floor_mattress',
#  'floor_penthouse',
#  'floor_plan',
#  'floor_plan_kitchen',
#  'floor_rear',
#  'floor_restaurant',
#  'floor_room',
#  'floor_sky',
#  'floor_sky_deck',
#  'floor_stair',
#  'floor_studio',
#  'floor_suite',
#  'floor_terrace',
#  'floor_townhouse',
#  'floor_unit',
#  'floor_walk',
#  'floor_walkup',
#  'foam_bed',
#  'foam_mattress',
#  'foam_topper',
#  'food_court',
#  'food_disposal',
#  'food_market',
#  'food_storage',
#  'foot_apartment',
#  'foot_ceiling',
#  'foot_roof',
#  'foot_roof_deck',
#  'foot_studio',
#  'foot_tub',
#  'football_stadium',
#  'free',
#  'freedom_trail',
#  'front_door',
#  'ft_',
#  'ft_apartment',
#  'ft_ceiling',
#  'ft_entertainment',
#  'ft_entertainment_complex',
#  'ft_floor',
#  'ft_screen',
#  'ft_townhouse',
#  'fun_neighborhood',
#  'fun_restaurant',
#  'function_room',
#  'furnished_studio',
#  'futon_bed',
#  'game_console',
#  'gaming_lounge',
#  'garage_parking',
#  'garbage_disposal',
#  'garbage_room',
#  'garden_area',
#  'garden_level',
#  'garden_level_apartment',
#  'garden_level_unit',
#  'garden_oasis',
#  'garden_patio',
#  'garden_studio',
#  'garden_view',
#  'gas_cooking',
#  'gas_fire',
#  'gas_fire_place',
#  'gas_fireplace',
#  'gas_grill',
#  'gas_lantern',
#  'gas_range',
#  'gas_station',
#  'gas_stove',
#  'gift_card',
#  'glass_counter',
#  'glass_door',
#  'glass_shower',
#  'glass_window',
#  'golf_course',
#  'gourmet_chef',
#  'gourmet_cooking',
#  'gourmet_cooking_need',
#  'gourmet_kitchen',
#  'gourmet_meal',
#  'government_center',
#  'graduate_student',
#  'granite_counter',
#  'granite_counter_',
#  'granite_counter_top',
#  'granite_countertop',
#  'granite_kitchen',
#  'granite_vanity',
#  'grill_area',
#  'grill_area_',
#  'grilling_area',
#  'grocery_shopping',
#  'grocery_store',
#  'ground_floor',
#  'ground_floor_townhouse',
#  'ground_level',
#  'group_class',
#  'group_seating',
#  'group_yoga',
#  'guest_bathroom',
#  'guest_bedroom',
#  'guest_book',
#  'guest_comment',
#  'guest_experienc',
#  'guest_experience',
#  'guest_experience_team',
#  'guest_room',
#  'guest_room_amenity',
#  'guest_suite',
#  'guest_use',
#  'guide_book',
#  'hair_dryer',
#  'half_bath',
#  'half_bathroom',
#  'hand_soap',
#  'hand_towel',
#  'harbor_view',
#  'hardwood',
#  'hardwood_floor',
#  'hardwood_flooring',
#  'hd_antenna',
#  'hd_cable',
#  'hd_television',
#  'head_shower',
#  'health_care',
#  'health_club',
#  'healthcare_worker',
#  'heating_system',
#  'herb_garden',
#  'hi_',
#  'hill_train',
#  'hip_area',
#  'hip_lounge',
#  'hip_restaurant',
#  'home_base',
#  'home_furnishing',
#  'home_office',
#  'home_washer',
#  'host_family',
#  'hotel_alternative',
#  'hotel_price',
#  'hotel_quality',
#  'hotel_room',
#  'hotel_setting',
#  'hotel_style',
#  'hour_access',
#  'hour_check',
#  'hour_concierge',
#  'hour_concierge_desk',
#  'hour_concierge_service',
#  'hour_concierge_service_',
#  'hour_customer',
#  'hour_customer_service',
#  'hour_doorman',
#  'hour_emergency',
#  'hour_emergency_maintenance',
#  'hour_emergency_maintenance_service',
#  'hour_fitness',
#  'hour_fitness_center',
#  'hour_grocery',
#  'hour_grocery_store',
#  'hour_guest',
#  'hour_guest_experienc',
#  'hour_guest_experience',
#  'hour_guest_experience_team',
#  'hour_limit',
#  'hour_parking',
#  'hour_security',
#  'hour_state',
#  'hour_supermarket',
#  'house_manager',
#  'house_manual',
#  'house_ware',
#  'housekeeping_service',
#  'hr_diner',
#  'hubway_',
#  'ice_cream',
#  'ice_maker',
#  'inch_flatscreen',
#  'inch_hdtv',
#  'inch_tv',
#  'inch_wall',
#  'infinity_pool',
#  'infinity_swimming',
#  'infinity_swimming_pool',
#  'internet_access',
#  'internet_connection',
#  'internet_lounge',
#  'internet_mapping',
#  'internet_mapping_site',
#  'internet_property',
#  'internet_property_amenity',
#  'internet_service',
#  'investment_property',
#  'iron_board',
#  'iron_fountain',
#  'iron_tub',
#  'jacuzzi_tub',
#  'jogging_path',
#  'jogging_route',
#  'jogging_trail',
#  'keypad_lock',
#  'kid_toy',
#  'king_bed',
#  'king_bedroom',
#  'king_size',
#  'king_size_bed',
#  'kitchen_access',
#  'kitchen_amenity',
#  'kitchen_appliance',
#  'kitchen_area',
#  'kitchen_counter',
#  'kitchen_counter_top',
#  'kitchen_countertop',
#  'kitchen_countertop_dishwasher',
#  'kitchen_electronic',
#  'kitchen_facility',
#  'kitchen_feature',
#  'kitchen_layout',
#  'kitchen_level',
#  'kitchen_privilege',
#  'kitchen_space',
#  'kitchen_table',
#  'kitchen_use',
#  'kitchen_utensil',
#  'lamp_',
#  'laptop_charger',
#  'launch_pad',
#  'laundry_room',
#  'law_attic',
#  'layout_kitchen',
#  'lease_term',
#  'leather_couch',
#  'leather_sectional',
#  'led_hdtv',
#  'led_tv',
#  'length_mirror',
#  'level_apartment',
#  'level_condo',
#  'level_loft',
#  'level_studio',
#  'level_unit',
#  'life_science',
#  'light',
#  'light_self',
#  'line_appliance',
#  'line_branch',
#  'line_bus',
#  'line_e',
#  'line_e_line',
#  'line_minute',
#  'line_service',
#  'line_station',
#  'line_subway',
#  'line_subway_stop',
#  'line_t',
#  'line_t_station',
#  'line_t_stop',
#  'line_train',
#  'linen_',
#  'linen_service',
#  'liquor_store',
#  'living',
#  'living_area',
#  'living_room',
#  'living_room_area',
#  'living_room_couch',
#  'living_room_layout',
#  'living_room_space',
#  'living_space',
#  'location_location',
#  'lock_box',
#  'locking_door',
#  'loft_apartment',
#  'loft_bed',
#  'loft_bedroom',
#  'loft_space',
#  'loft_style',
#  'lounge_area',
#  'lounge_chair',
#  'lounge_furniture',
#  'lounge_seating',
#  'love_seat',
#  'luxury_apartment',
#  'luxury_apartment_building',
#  'luxury_apartment_residence',
#  'luxury_bathroom',
#  'luxury_bed',
#  'luxury_building',
#  'luxury_condo',
#  'luxury_finish',
#  'luxury_kitchen',
#  'luxury_pillow',
#  'luxury_unit',
#  'maintenance_service',
#  'management_company',
#  'map_app',
#  'maple_cabinet',
#  'maple_floor',
#  'mapping_site',
#  'marathon_week',
#  'marble_bath',
#  'marble_bathroom',
#  'marble_counter',
#  'marble_countertop',
#  'marble_fireplace',
#  'marble_island',
#  'marble_mantel',
#  'marble_mantle',
#  'marble_shower',
#  'marble_table',
#  'market_place',
#  'market_shop',
#  'massage_chair',
#  'master_bath',
#  'master_bathroom',
#  'master_bedroom',
#  'master_suite',
#  'mat_right',
#  'mattress_topper',
#  'meal_preparation',
#  'meeting_room',
#  'memory_foam',
#  'memory_foam_bed',
#  'memory_foam_mattress',
#  'memory_foam_topper',
#  'memory_mattress',
#  'meter_parking',
#  'metro_station',
#  'mid_',
#  'mile_walk',
#  'min',
#  'min_bus',
#  'min_drive',
#  'min_ride',
#  'min_t',
#  'min_t_ride',
#  'min_taxi',
#  'min_walk',
#  'min_walking',
#  'min_walking_distance',
#  'mini_',
#  'minimum_stay',
#  'minimum_stay_policy',
#  'minute_bus',
#  'minute_bus_ride',
#  'minute_cab',
#  'minute_drive',
#  'minute_ride',
#  'minute_ride_downtown',
#  'minute_subway',
#  'minute_subway_ride',
#  'minute_t',
#  'minute_t_ride',
#  'minute_train',
#  'minute_train_ride',
#  'minute_walk',
#  'minute_walking',
#  'minute_walking_distance',
#  'mobility_issue',
#  'month_promotion',
#  'month_stay',
#  'morning_coffee',
#  'morning_light',
#  'morning_shift',
#  'morning_sun',
#  'movie_channel',
#  'movie_projector',
#  'movie_projector_w',
#  'movie_theater',
#  'murphy_bed',
#  'music_room',
#  'music_system',
#  'music_venue',
#  'neighborhood_child',
#  'neighborhood_feature',
#  'neighborhood_feel',
#  'neighborhood_host',
#  'neighborhood_restaurant',
#  'neighborhood_standout',
#  'neighboring_house',
#  'night_life',
#  'night_minimum',
#  'night_minimum_stay',
#  'night_minimum_stay_policy',
#  'night_parking',
#  'night_sleep',
#  'night_stand',
#  'night_stay',
#  'night_table',
#  'nightlife_area',
#  'no_elevator',
#  'north_end',
#  'novice_visitor',
#  'number_hidden',
#  'oak_floor',
#  'observation_deck',
#  'occupancy_bathroom',
#  'ocean_breeze',
#  'ocean_view',
#  'office_alcove',
#  'office_area',
#  'office_desk',
#  'office_space',
#  'op_laundr',
#  'op_laundry',
#  'op_washer',
#  'opera_singer',
#  'orange_bus',
#  'orange_bus_line',
#  'orange_line',
#  'out_sofa',
#  'package_delivery',
#  'panel_tv',
#  'paper_towel',
#  'park_zoo',
#  'parking_garage',
#  'parking_lot',
#  'parking_on',
#  'parking_option',
#  'parking_place',
#  'parking_space',
#  'parking_spot',
#  'parlor_level',
#  'parlor_level_apartment',
#  'parquet_floor',
#  'parquet_wood',
#  'parquet_wood_floor',
#  'party_house',
#  'pastry_shop',
#  'patio_area',
#  'patio_e',
#  'patio_e_',
#  'patio_furniture',
#  'patio_space',
#  'pay_washer',
#  'peak_season',
#  'penthouse_apartment',
#  'penthouse_duplex',
#  'penthouse_level',
#  'penthouse_treetop',
#  'penthouse_treetop_unit',
#  'penthouse_unit',
#  'period_detail',
#  'period_feature',
#  'period_iron',
#  'period_molding',
#  'person_dining',
#  'person_dining_room',
#  'person_dining_room_table',
#  'person_table',
#  'phone_call',
#  'phone_line',
#  'phone_number',
#  'phone_number_hidden',
#  'phone_service',
#  'phone_service_utility',
#  'picnic_table',
#  'pizza_place',
#  'plan_kitchen',
#  'plan_living',
#  'plan_living_room',
#  'planet_fitness',
#  'plant_life',
#  'plasma_tv',
#  'platform_bed',
#  'platform_queen',
#  'platform_queen_bed',
#  'play_area',
#  'pocket_door',
#  'police_station',
#  ...]
